# %% [markdown]
# ## POS tagging using modified Viterbi

# %% [markdown]
# ### Data Preparation

# %%
#Importing libraries
import nltk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import pprint, time
from sklearn.model_selection import train_test_split

# %%
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     /Users/natashapandya/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %%
# reading the Treebank tagged sentences
nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
len(nltk_data)
# Out:
# 3914

# %% [markdown]
# ### Reading sample file as well to validate later

# %%
file = open('Test_sentences.txt', 'r') 
validation_data =  file.read()

# %%
validation_tokens = nltk.word_tokenize(validation_data)

# %% [markdown]
# ### Splitting data into train and test set

# %%
#Spliting in train and test set
random.seed(1234)
train_set, test_set = train_test_split(nltk_data, test_size=0.05)

# %%
print(len(train_set))
print(len(test_set))
print(test_set[:40])
# Out:
# 3718
# 196
# [[('-LCB-', '.'), ('The', 'DET'), ('court', 'NOUN'), ('has', 'VERB'), ('indicated', 'VERB'), ('0', 'X'), ('it', 'PRON'), ('will', 'VERB'), ('rule', 'VERB'), ('on', 'ADP'), ('the', 'DET'), ('case', 'NOUN'), ('by', 'ADP'), ('the', 'DET'), ('end', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('month', 'NOUN'), ('.', '.'), ('-RCB-', '.')], [('--', '.'), ('Pat', 'NOUN'), ("D'Amico", 'NOUN'), ('.', '.')], [('Many', 'ADJ'), ('banks', 'NOUN'), (',', '.'), ('particularly', 'ADV'), ('smaller', 'ADJ'), ('ones', 'NOUN'), (',', '.'), ('were', 'VERB'), ('slow', 'ADJ'), ('*-1', 'X'), ('to', 'PRT'), ('computerize', 'VERB'), ('and', 'CONJ'), ('could', 'VERB'), ("n't", 'ADV'), ('target', 'VERB'), ('market', 'NOUN'), ('niches', 'NOUN'), ('that', 'DET'), ('*T*-199', 'X'), ('would', 'VERB'), ('have', 'VERB'), ('made', 'VERB'), ('the', 'DET'), ('programs', 'NOUN'), ('more', 'ADV'), ('profitable', 'ADJ'), ('.', '.')], [('Friends', 'NOUN'), ('of', 'ADP'), ('Education', 'NOUN'), ('rates', 'VERB'), ('South', 'NOUN'), ('Carolina', 'NOUN'), ('one', 'NUM'), ('of', 'ADP'), ('the', 'DET'), ('worst', 'ADJ'), ('seven', 'NUM'), ('states', 'NOUN'), ('in', 'ADP'), ('its', 'PRON'), ('study', 'NOUN'), ('on', 'ADP'), ('academic', 'ADJ'), ('cheating', 'NOUN'), ('.', '.')], [('Dealers', 'NOUN'), ('said', 'VERB'), ('0', 'X'), ('the', 'DET'), ('U.K.', 'NOUN'), ('government', 'NOUN'), ("'s", 'PRT'), ('decision', 'NOUN'), ('*ICH*-1', 'X'), ('Tuesday', 'NOUN'), ('*', 'X'), ('to', 'PRT'), ('waive', 'VERB'), ('its', 'PRON'), ('protective', 'ADJ'), ('``', '.'), ('golden', 'ADJ'), ('share', 'NOUN'), ("''", '.'), ('in', 'ADP'), ('the', 'DET'), ('auto', 'NOUN'), ('maker', 'NOUN'), ('raised', 'VERB'), ('prospects', 'NOUN'), ('of', 'ADP'), ('a', 'DET'), ('bidding', 'NOUN'), ('war', 'NOUN'), ('between', 'ADP'), ('the', 'DET'), ('two', 'NUM'), ('U.S.', 'NOUN'), ('auto', 'NOUN'), ('giants', 'NOUN'), ('.', '.')], [('Similarly', 'ADV'), (',', '.'), ('Campbell', 'NOUN'), ("'s", 'PRT'), ('Italian', 'ADJ'), ('biscuit', 'NOUN'), ('operation', 'NOUN'), (',', '.'), ('D.', 'NOUN'), ('Lazzaroni', 'NOUN'), ('&', 'CONJ'), ('Co.', 'NOUN'), (',', '.'), ('has', 'VERB'), ('been', 'VERB'), ('hurt', 'VERB'), ('*-40', 'X'), ('by', 'ADP'), ('overproduction', 'NOUN'), ('and', 'CONJ'), ('distribution', 'NOUN'), ('problems', 'NOUN'), ('.', '.')], [('The', 'DET'), ('governor', 'NOUN'), ('could', 'VERB'), ("n't", 'ADV'), ('make', 'VERB'), ('it', 'PRON'), (',', '.'), ('so', 'ADP'), ('the', 'DET'), ('lieutenant', 'NOUN'), ('governor', 'NOUN'), ('welcomed', 'VERB'), ('the', 'DET'), ('special', 'ADJ'), ('guests', 'NOUN'), ('.', '.')], [('Foreign', 'NOUN'), ('Bond', 'NOUN')], [('Victor', 'NOUN'), ('Stanley', 'NOUN'), ('Fishman', 'NOUN'), (',', '.'), ('Longwood', 'NOUN'), (',', '.'), ('Fla.', 'NOUN'), (',', '.'), ('fined', 'VERB'), ('*-1', 'X'), ('$', '.'), ('25,000', 'NUM'), ('*U*', 'X'), (';', '.'), ('William', 'NOUN'), ('Harold', 'NOUN'), ('Floyd', 'NOUN'), (',', '.'), ('Houston', 'NOUN'), (',', '.'), ('$', '.'), ('100,000', 'NUM'), ('*U*', 'X'), (';', '.'), ('Michael', 'NOUN'), ('Anthony', 'NOUN'), ('Houston', 'NOUN'), (',', '.'), ('Bronx', 'NOUN'), (',', '.'), ('N.Y.', 'NOUN'), (',', '.'), ('$', '.'), ('15,000', 'NUM'), ('*U*', 'X'), (';', '.'), ('Amin', 'NOUN'), ('Jalaalwalikraam', 'NOUN'), (',', '.'), ('Glenham', 'NOUN'), (',', '.'), ('N.Y.', 'NOUN'), (',', '.'), ('$', '.'), ('60,000', 'NUM'), ('*U*', 'X'), (';', '.'), ('Richard', 'NOUN'), ('F.', 'NOUN'), ('Knapp', 'NOUN'), (',', '.'), ('London', 'NOUN'), (',', '.'), ('$', '.'), ('10,000', 'NUM'), ('*U*', 'X'), ('and', 'CONJ'), ('30-day', 'ADJ'), ('suspension', 'NOUN'), (';', '.'), ('Deborah', 'NOUN'), ('Renee', 'NOUN'), ('Martin', 'NOUN'), (',', '.'), ('St.', 'NOUN'), ('Louis', 'NOUN'), (',', '.'), ('$', '.'), ('15,000', 'NUM'), ('*U*', 'X'), (';', '.'), ('Joseph', 'NOUN'), ('Francis', 'NOUN'), ('Muscolina', 'NOUN'), ('Jr.', 'NOUN'), (',', '.'), ('Palisades', 'NOUN'), ('Park', 'NOUN'), (',', '.'), ('N.J.', 'NOUN'), (',', '.'), ('$', '.'), ('15,000', 'NUM'), (' ...

# %% [markdown]
# #### Analyzing data

# %%
train_tagged_words = [tup for sent in train_set for tup in sent]
train_tagged_words
# Out:
# [('Modifications', 'NOUN'),
#  ('*ICH*-3', 'X'),
#  ('had', 'VERB'),
#  ('been', 'VERB'),
#  ('made', 'VERB'),
#  ('*-80', 'X'),
#  ('to', 'PRT'),
#  ('the', 'DET'),
#  ('Souper', 'NOUN'),
#  ('Combo', 'NOUN'),
#  ('product', 'NOUN'),
#  ('at', 'ADP'),
#  ('the', 'DET'),
#  ('time', 'NOUN'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('issue', 'NOUN'),
#  ('was', 'VERB'),
#  ('printed', 'VERB'),
#  ('*-81', 'X'),
#  ('*T*-1', 'X'),
#  (',', '.'),
#  ('he', 'PRON'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  (',', '.'),
#  ('*-80', 'X'),
#  ('making', 'VERB'),
#  ('it', 'PRON'),
#  ('less', 'ADJ'),
#  ('an', 'DET'),
#  ('offender', 'NOUN'),
#  ('than', 'ADP'),
#  ('*', 'X'),
#  ('was', 'VERB'),
#  ('portrayed', 'VERB'),
#  ('*-4', 'X'),
#  ('.', '.'),
#  ('Areas', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('factory', 'NOUN'),
#  ('*ICH*-2', 'X'),
#  ('were', 'VERB'),
#  ('particularly', 'ADV'),
#  ('dusty', 'ADJ'),
#  ('where', 'ADV'),
#  ('the', 'DET'),
#  ('crocidolite', 'NOUN'),
#  ('was', 'VERB'),
#  ('used', 'VERB'),
#  ('*-8', 'X'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('Free', 'NOUN'),
#  ('State', 'NOUN'),
#  ('Glass', 'NOUN'),
#  ('Industries', 'NOUN'),
#  ('of', 'ADP'),
#  ('Warrenton', 'NOUN'),
#  (',', '.'),
#  ('Va.', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('small', 'ADJ'),
#  ('fabricator', 'NOUN'),
#  ('of', 'ADP'),
#  ('architectural', 'ADJ'),
#  ('glass', 'NOUN'),
#  (',', '.'),
#  ('was', 'VERB'),
#  ('foundering', 'VERB'),
#  ('under', 'ADP'),
#  ('its', 'PRON'),
#  ('original', 'ADJ'),
#  ('management', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('Purchasing', 'NOUN'),
#  ('Management', 'NOUN'),
#  ('Association', 'NOUN'),
#  ('of', 'ADP'),
#  ('Chicago', 'NOUN'),
#  ("'s", 'PRT'),
#  ('October', 'NOUN'),
#  ('index', 'NOUN'),
#  ('rose', 'VERB'),
#  ('to', 'PRT'),
#  ('51.6', 'NUM'),
#  ('%', 'NOUN'),
#  ('after', 'ADP'),
#  ('three', 'NUM'),
#  ('previous', 'ADJ'),
#  ('months', 'NOUN'),
#  ('of', 'ADP'),
#  ('readings', 'NOUN'),
#  ('below', 'ADP'),
#  ('50', 'NUM'),
#  ('%', 'NOUN'),
#  ('.', '.'),
#  ('But', 'CONJ'),
#  ('the', 'DET'),
#  ('heated', 'VERB'),
#  ('fight', 'NOUN'),
#  ('over', 'ADP'),
#  ('program', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('is', 'VERB'),
#  ('about', 'ADP'),
#  ('much', 'ADV'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('a', 'DET'),
#  ('volatile', 'ADJ'),
#  ('stock', 'NOUN'),
#  ('market', 'NOUN'),
#  ('.', '.'),
#  ('Now', 'ADV'),
#  (',', '.'),
#  ('he', 'PRON'),
#  ('plans', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('sell', 'VERB'),
#  ('all', 'DET'),
#  ('his', 'PRON'),
#  ('stocks', 'NOUN'),
#  ('by', 'ADP'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('quarter', 'NOUN'),
#  ('of', 'ADP'),
#  ('1990', 'NUM'),
#  ('.', '.'),
#  ('``', '.'),
#  ('New', 'ADJ'),
#  ('managers', 'NOUN'),
#  ('would', 'VERB'),
#  ('think', 'VERB'),
#  ('a', 'DET'),
#  ('little', 'ADV'),
#  ('more', 'ADJ'),
#  ('like', 'ADP'),
#  ('Wall', 'NOUN'),
#  ('Street', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('Mr.', 'NOUN'),
#  ('McMillin', 'NOUN'),
#  ('added', 'VERB'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('Japanese', 'ADJ'),
#  ('industrial', 'ADJ'),
#  ('companies', 'NOUN'),
#  ('should', 'VERB'),
#  ('know', 'VERB'),
#  ('better', 'ADJ'),
#  ('.', '.'),
#  ('Mr.', 'NOUN'),
#  ('Jennison', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('Northeast', 'NOUN'),
#  ('Bancorp', 'NOUN'),
#  ('also', 'ADV'),
#  ('fared', 'VERB'),
#  ('well', 'ADV'),
#  ('because', 'ADP'),
#  ('takeover', 'NOUN'),
#  ('stocks', 'NOUN'),
#  ('have', 'VERB'),
#  ('returned', 'VERB'),
#  ('to', 'PRT'),
#  ('favor', 'VERB'),
#  ('among', 'ADP'),
#  ('investors', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('Wall', 'NOUN'),
#  ('Street', 'NOUN'),
#  ('is', 'VERB'),
#  ('facing', 'VERB'),
#  ('a', 'DET'),
#  ('Catch-22', 'NOUN'),
#  ('situation', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('says', 'VERB'),
#  ('*T*-1', 'X'),
#  ('Mr.', 'NOUN'),
#  ('Mahoney', 'NOUN'),
#  ('of', 'ADP'),
#  ('Moody', 'NOUN'),
#  ("'s", 'PRT'),
#  ('.', '.'),
#  ('Wednesday', 'NOUN'),
#  ("'s", 'PRT'),
#  ('dominant', 'ADJ'),
#  ('issue', 'NOUN'),
#  ('was', 'VERB'),
#  ('Yasuda', 'NOUN'),
#  ('Fire', 'NOUN'),
#  ('&', 'CONJ'),
#  ('Marine', 'NOUN'),
#  ('Insurance', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-1', 'X'),
#  ('continued', 'VERB'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('surge', 'VERB'),
#  ('on', 'ADP'),
#  ('rumors', 'NOUN'),
#  ('of', 'ADP'),
#  ('speculative', 'ADJ'),
#  ('buying', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('There', 'DET'),
#  ('may', 'VERB'),
#  ('be', 'VERB'),
#  ('sticker-shock', 'NOUN'),
#  ('reaction', 'NOUN'),
#  ('initially', 'ADV'),
#  (',', '.'),
#  ("''", '.'),
#  ('said', 'VERB'),
#  ('*T*-2', 'X'),
#  ('Mr.', 'NOUN'),
#  ('Pratt', 'NOUN'),
#  (',', '.'),
#  ('``', '.'),
#  ('but', 'CONJ'),
#  ('as', 'ADP'),
#  ('the', 'DET'),
#  ('wine', 'NOUN'),
#  ('is', 'VERB'),
#  ('talked', 'VERB'),
#  ('about', 'ADP'),
#  ('*-1', 'X'),
#  ('and', 'CONJ'),
#  ('starts', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('sell', 'VERB'),
#  (',', '.'),
#  ('they', 'PRON'),
#  ('eventually', 'ADV'),
#  ('get', 'VERB'),
#  ('excited', 'VERB'),
#  ('and', 'CONJ'),
#  ('decide', 'VERB'),
#  ('0', 'X'),
#  ('it', 'PRON'),
#  ("'s", 'VERB'),
#  ('worth', 'ADJ'),
#  ('the', 'DET'),
#  ('astronomical', 'ADJ'),
#  ('price', 'NOUN'),
#  ('*-3', 'X'),
#  ('to', 'PRT'),
#  ('add', 'VERB'),
#  ('it', 'PRON'),
#  ('to', 'PRT'),
#  ('their', 'PRON'),
#  ('collection', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('The', 'DET'),
#  ('reason', 'NOUN'),
#  (':', '.'),
#  ('the', 'DET'),
#  ('refusal', 'NOUN'),
#  ('*ICH*-1', 'X'),
#  ('of', 'ADP'),
#  ('Congress', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('give', 'VERB'),
#  ('federal', 'ADJ'),
#  ('judges', 'NOUN'),
#  ('a', 'DET'),
#  ('raise', 'NOUN'),
#  ('.', '.'),
#  ('Advancing', 'VERB'),
#  ('stocks', 'NOUN'),
#  ('led', 'VERB'),
#  ('decliners', 'NOUN'),
#  ('on', 'ADP'),
#  ('the', 'DET'),
#  ('New', 'NOUN'),
#  ('York', 'NOUN'),
#  ('Stock', 'NOUN'),
#  ('Exchange', 'NOUN'),
#  ('by', 'ADP'),
#  ('847', 'NUM'),
#  ('to', 'PRT'),
#  ('644', 'NUM'),
#  ('.', '.'),
#  ('Takuma', 'NOUN'),
#  ('Yamamoto', 'NOUN'),
#  (',', '.'),
#  ('president', 'NOUN'),
#  ('of', 'ADP'),
#  ('Fujitsu', 'NOUN'),
#  ('Ltd.', 'NOUN'),
#  (',', '.'),
#  ('believes', 'VERB'),
#  ('``', '.'),
#  ('0', 'X'),
#  ('the', 'DET'),
#  ('`', '.'),
#  ('money', 'NOUN'),
#  ('worship', 'NOUN'),
#  ("'", '.'),
#  ('among', 'ADP'),
#  ('young', 'ADJ'),
#  ('people', 'NOUN'),
#  ('...', '.'),
#  ('caused', 'VERB'),
#  ('the', 'DET'),
#  ('problem', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('The', 'DET'),
#  ('radio', 'NOUN'),
#  ('show', 'NOUN'),
#  ('``', '.'),
#  ('enraged', 'VERB'),
#  ('us', 'PRON'),
#  (',', '.'),
#  ("''", '.'),
#  ('says', 'VERB'),
#  ('*T*-1', 'X'),
#  ('Mrs.', 'NOUN'),
#  ('Ward', 'NOUN'),
#  ('.', '.'),
#  ('Mr.', 'NOUN'),
#  ('Oxnard', 'NOUN'),
#  ('observed', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('situation', 'NOUN'),
#  ('in', 'ADP'),
#  ('Brazil', 'NOUN'),
#  ('is', 'VERB'),
#  ('also', 'ADV'),
#  ('very', 'ADV'),
#  ('complicated', 'VERB'),
#  ('.', '.'),
#  ('If', 'ADP'),
#  ('government', 'NOUN'),
#  ('or', 'CONJ'),
#  ('private', 'ADJ'),
#  ('watchdogs', 'NOUN'),
#  ('insist', 'VERB'),
#  (',', '.'),
#  ('however', 'ADV'),
#  (',', '.'),
#  ('on', 'ADP'),
#  ('*', 'X'),
#  ('introducing', 'VERB'),
#  ('greater', 'ADJ'),
#  ('friction', 'NOUN'),
#  ('between', 'ADP'),
#  ('the', 'DET'),
#  ('markets', 'NOUN'),
#  ('-LRB-', '.'),
#  ('limits', 'NOUN'),
#  ('on', 'ADP'),
#  ('price', 'NOUN'),
#  ('moves', 'NOUN'),
#  (',', '.'),
#  ('two-tiered', 'ADJ'),
#  ('execution', 'NOUN'),
#  (',', '.'),
#  ('higher', 'ADJ'),
#  ('margin', 'NOUN'),
#  ('requirements', 'NOUN'),
#  (',', '.'),
#  ('taxation', 'NOUN'),
#  (',', '.'),
#  ('etc.', 'X'),
#  ('-RRB-', '.'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('end', 'NOUN'),
#  ('loser', 'NOUN'),
#  ('will', 'VERB'),
#  ('be', 'VERB'),
#  ('the', 'DET'),
#  ('markets', 'NOUN'),
#  ('themselves', 'PRON'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('1988', 'NUM'),
#  ('trade', 'NOUN'),
#  ('act', 'NOUN'),
#  ('requires', 'VERB'),
#  ('Mrs.', 'NOUN'),
#  ('Hills', 'NOUN'),
#  ('to', 'PRT'),
#  ('issue', 'VERB'),
#  ('another', 'DET'),
#  ('review', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('performance', 'NOUN'),
#  ('of', 'ADP'),
#  ('these', 'DET'),
#  ('countries', 'NOUN'),
#  ('by', 'ADP'),
#  ('April', 'NOUN'),
#  ('30', 'NUM'),
#  ('.', '.'),
#  ('Mr.', 'NOUN'),
#  ('McGuigan', 'NOUN'),
#  ('cites', 'VERB'),
#  ('three', 'NUM'),
#  ('completed', 'VERB'),
#  ('efforts', 'NOUN'),
#  ('in', 'ADP'),
#  ('Oklahoma', 'NOUN'),
#  ('.', '.'),
#  ('That', 'DET'),
#  ('compares', 'VERB'),
#  ('with', 'ADP'),
#  ('operating', 'VERB'),
#  ('earnings', 'NOUN'),
#  ('of', 'ADP'),
#  ('$', '.'),
#  ('132.9', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  (',', '.'),
#  ('or', 'CONJ'),
#  ('49', 'NUM'),
#  ('cents', 'NOUN'),
#  ('a', 'DET'),
#  ('share', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('year', 'NOUN'),
#  ('earlier', 'ADJ'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('May', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('two', 'NUM'),
#  ('companies', 'NOUN'),
#  (',', '.'),
#  ('through', 'ADP'),
#  ('their', 'PRON'),
#  ('jointly', 'ADV'),
#  ('owned', 'VERB'),
#  ('holding', 'VERB'),
#  ('company', 'NOUN'),
#  (',', '.'),
#  ('Temple', 'NOUN'),
#  (',', '.'),
#  ('offered', 'VERB'),
#  ('$', '.'),
#  ('50', 'NUM'),
#  ('*U*', 'X'),
#  ('a', 'DET'),
#  ('share', 'NOUN'),
#  (',', '.'),
#  ('or', 'CONJ'),
#  ('$', '.'),
#  ('777', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  (',', '.'),
#  ('for', 'ADP'),
#  ('Sea', 'NOUN'),
#  ('Containers', 'NOUN'),
#  ('.', '.'),
#  ('Note', 'VERB'),
#  (':', '.'),
#  ('All', 'DET'),
#  ('per-share', 'ADJ'),
#  ('figures', 'NOUN'),
#  ('are', 'VERB'),
#  ('fully', 'ADV'),
#  ('diluted', 'VERB'),
#  ('.', '.'),
#  ('Also', 'ADV'),
#  (',', '.'),
#  ('ringers', 'NOUN'),
#  ('do', 'VERB'),
#  ("n't", 'ADV'),
#  ('always', 'ADV'),
#  ('live', 'VERB'),
#  ('where', 'ADV'),
#  ('the', 'DET'),
#  ('bells', 'NOUN'),
#  ('need', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('rung', 'VERB'),
#  ('*-140', 'X'),
#  ('*T*-2', 'X'),
#  ('--', '.'),
#  ('like', 'ADP'),
#  ('in', 'ADP'),
#  ('small', 'ADJ'),
#  (',', '.'),
#  ('rural', 'ADJ'),
#  ('parishes', 'NOUN'),
#  ('and', 'CONJ'),
#  ('inner-city', 'NOUN'),
#  ('churches', 'NOUN'),
#  ('.', '.'),
#  ('In', 'ADP'),
#  ('*', 'X'),
#  ('quoting', 'VERB'),
#  ('from', 'ADP'),
#  ('our', 'PRON'),
#  ('research', 'NOUN'),
#  ('you', 'PRON'),
#  ('emphasized', 'VERB'),
#  ('the', 'DET'),
#  ('high', 'ADJ'),
#  ('prevalance', 'NOUN'),
#  ('of', 'ADP'),
#  ('mental', 'ADJ'),
#  ('illness', 'NOUN'),
#  ('and', 'CONJ'),
#  ('alcoholism', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ("'s", 'PRT'),
#  ('directors', 'NOUN'),
#  ('meet', 'VERB'),
#  ('today', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('approve', 'VERB'),
#  ('some', 'DET'),
#  ('program-trading', 'ADJ'),
#  ('restrictions', 'NOUN'),
#  (',', '.'),
#  ('but', 'CONJ'),
#  ('a', 'DET'),
#  ('total', 'ADJ'),
#  ('ban', 'NOUN'),
#  ('is', 'VERB'),
#  ("n't", 'ADV'),
#  ('being', 'VERB'),
#  ('considered', 'VERB'),
#  ('*-77', 'X'),
#  (',', '.'),
#  ('Big', 'NOUN'),
#  ('Board', 'NOUN'),
#  ('officials', 'NOUN'),
#  ('say', 'VERB'),
#  ('0', 'X'),
#  ('*T*-2', 'X'),
#  ('.', '.'),
#  ('Earlier', 'ADJ'),
#  ('this', 'DET'),
#  ('year', 'NOUN'),
#  (',', '.'),
#  ('Japanese', 'ADJ'),
#  ('investors', 'NOUN'),
#  ('snapped', 'VERB'),
#  ('up', 'PRT'),
#  ('a', 'DET'),
#  ('similar', 'ADJ'),
#  (',', '.'),
#  ('$', '.'),
#  ('570', 'NUM'),
#  ('million', 'NUM'),
#  ('*U*', 'X'),
#  ('mortgage-backed', 'ADJ'),
#  ('securities', 'NOUN'),
#  ('mutual', 'ADJ'),
#  ('fund', 'NOUN'),
#  ('.', '.'),
#  ('A', 'DET'),
#  ('study', 'NOUN'),
#  ('by', 'ADP'),
#  ('Tulane', 'NOUN'),
#  ('Prof.', 'NOUN'),
#  ('James', 'NOUN'),
#  ('Wright', 'NOUN'),
#  ('says', 'VERB'),
#  ('0', 'X'),
#  ('homelessness', 'NOUN'),
#  ('is', 'VERB'),
#  ('due', 'ADJ'),
#  ('to', 'PRT'),
#  ('a', 'DET'),
#  ('complex', 'ADJ'),
#  ('array', 'NOUN'),
#  ('of', 'ADP'),
#  ('problems', 'NOUN'),
#  (',', '.'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('common', 'ADJ'),
#  ('thread', 'NOUN'),
#  ('of', 'ADP'),
#  ('poverty', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('discussions', 'NOUN'),
#  ('are', 'VERB'),
#  ('still', 'ADV'),
#  ('in', 'ADP'),
#  ('preliminary', 'ADJ'),
#  ('stages', 'NOUN'),
#  (',', '.'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('specific', 'ADJ'),
#  ('details', 'NOUN'),
#  ('have', 'VERB'),
#  ("n't", 'ADV'),
#  ('been', 'VERB'),
#  ('worked', 'VERB'),
#  ('*-2', 'X'),
#  ('out', 'PRT'),
#  ('between', 'ADP'),
#  ('the', 'DET'),
#  ('Seattle', 'NOUN'),
#  ('aerospace', 'NOUN'),
#  ('company', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Kawasaki', 'NOUN'),
#  ('Heavy', 'NOUN'),
#  ('Industries', 'NOUN'),
#  ('Ltd.', 'NOUN'),
#  (',', '.'),
#  ('Mitsubishi', 'NOUN'),
#  ('Heavy', 'NOUN'),
#  ('Industries', 'NOUN'),
#  ('Ltd.', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Fuji', 'NOUN'),
#  ('Heavy', 'NOUN'),
#  ('Industries', 'NOUN'),
#  ('Ltd', 'NOUN'),
#  ('.', '.'),
#  ('Always', 'ADV'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('first', 'ADJ'),
#  ('Champagne', 'NOUN'),
#  ('0', 'X'),
#  ('*T*-1', 'X'),
#  ('to', 'PRT'),
#  ('crack', 'VERB'),
#  ('that', 'DET'),
#  ('price', 'NOUN'),
#  ('barrier', 'NOUN'),
#  ('was', 'VERB'),
#  ('the', 'DET'),
#  ('1979', 'NUM'),
#  ('Salon', 'NOUN'),
#  ('de', 'ADP'),
#  ('Mesnil', 'NOUN'),
#  ('Blanc', 'NOUN'),
#  ('de', 'ADP'),
#  ('Blancs', 'NOUN'),
#  ('.', '.'),
#  ('Indeed', 'ADV'),
#  (',', '.'),
#  ('Mrs.', 'NOUN'),
#  ('Yeargin', 'NOUN'),
#  ('was', 'VERB'),
#  ('interested', 'ADJ'),
#  ('in', 'ADP'),
#  ('a', 'DET'),
#  ('possible', 'ADJ'),
#  ('job', 'NOUN'),
#  ('with', 'ADP'),
#  ('the', 'DET'),
#  ('state', 'NOUN'),
#  ('teacher', 'NOUN'),
#  ('cadet', 'NOUN'),
#  ('program', 'NOUN'),
#  ('.', '.'),
#  ('Mr.', 'NOUN'),
#  ('Ross', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('he', 'PRON'),
#  ('met', 'VERB'),
#  ('with', 'ADP'),
#  ('officials', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('IRS', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('Justice', 'NOUN'),
#  ('Department', 'NOUN'),
#  (',', '.'),
#  ('which', 'DET'),
#  ('*T*-133', 'X'),
#  ('would', 'VERB'),
#  ('bring', 'VERB'),
#  ('any', 'DET'),
#  ('enforcement', 'NOUN'),
#  ('actions', 'NOUN'),
#  ('against', 'ADP'),
#  ('taxpayers', 'NOUN'),
#  (',', '.'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('discuss', 'VERB'),
#  ('the', 'DET'),
#  ('issue', 'NOUN'),
#  ('last', 'ADJ'),
#  ('May', 'NOUN'),
#  ('.', '.'),
#  ('Although', 'ADP'),
#  ('the', 'DET'),
#  ('Hammersmith', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Fulham', 'NOUN'),
#  ('council', 'NOUN'),
#  ('was', 'VERB'),
#  ('by', 'ADP'),
#  ('far', 'ADV'),
#  ('the', 'DET'),
#  ('most', 'ADV'),
#  ('active', 'ADJ'),
#  ('local', 'ADJ'),
#  ('authority', 'NOUN'),
#  ('engaging', 'VERB'),
#  ('in', 'ADP'),
#  ('such', 'ADJ'),
#  ('capital-markets', 'ADJ'),
#  ('transactions', 'NOUN'),
#  (',', '.'),
#  ('the', 'DET'),
#  ('court', 'NOUN'),
#  ('decision', 'NOUN'),
#  ('could', 'VERB'),
#  ('set', 'VERB'),
#  ('a', 'DET'),
#  ('precedent', 'NOUN'),
#  ('for', 'ADP'),
#  ('similar', 'ADJ'),
#  ('transactions', 'NOUN'),
#  ('by', 'ADP'),
#  ('77', 'NUM'),
#  ('other', 'ADJ'),
#  ('local', 'ADJ'),
#  ('councils', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('The', 'DET'),
#  ('First', 'NOUN'),
#  ('Amendment', 'NOUN'),
#  ('does', 'VERB'),
#  ('not', 'ADV'),
#  ('prescribe', 'VERB'),
#  ('a', 'DET'),
#  ('duty', 'NOUN'),
#  ('upon', 'ADP'),
#  ('the', 'DET'),
#  ('government', 'NOUN'),
#  ('*', 'X'),
#  ('to', 'PRT'),
#  ('assure', 'VERB'),
#  ('easy', 'ADJ'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('information', 'NOUN'),
#  ('for', 'ADP'),
#  ('members', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('press', 'NOUN'),
#  ('.', '.'),
#  ("''", '.'),
#  ('The', 'DET'),
#  ('Underwood', 'NOUN'),
#  ('family', 'NOUN'),
#  ('said', 'VERB'),
#  ('that', 'ADP'),
#  ('holders', 'NOUN'),
#  ('of', 'ADP'),
#  ('more', 'ADJ'),
#  ('than', 'ADP'),
#  ('a', 'DET'),
#  ('majority', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('stock', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('company', 'NOUN'),
#  ('have', 'VERB'),
#  ('approved', 'VERB'),
#  ('the', 'DET'),
#  ('transaction', 'NOUN'),
#  ('by', 'ADP'),
#  ('written', 'VERB'),
#  ('consent', 'NOUN'),
#  ('.', '.'),
#  ('We', 'PRON'),
#  ('must', 'VERB'),
#  ('be', 'VERB'),
#  ('very', 'ADV'),
#  ('cautious', 'ADJ'),
#  ('about', 'ADP'),
#  ('*', 'X'),
#  ('labeling', 'VERB'),
#  ('investors', 'NOUN'),
#  ('as', 'ADP'),
#  ('``', '.'),
#  ('long-term', 'ADJ'),
#  ("''", '.'),
#  ('or', 'CONJ'),
#  ('``', '.'),
#  ('short-term', 'ADJ'),
#  ('.', '.'),
#  ("''", '.'),
#  ('He', 'PRON'),
#  ('succeeds', 'VERB'),
#  ('James', 'NOUN'),
#  ('A.', 'NOUN'),
#  ('Taylor', 'NOUN'),
#  (',', '.'),
#  ('who', 'PRON'),
#  ('*T*-1', 'X'),
#  ('stepped', 'VERB'),
#  ('down', 'PRT'),
#  ('as', 'ADP'),
#  ('chairman', 'NOUN'),
#  (',', '.'),
#  ('president', 'NOUN'),
#  ('and', 'CONJ'),
#  ('chief', 'NOUN'),
#  ('executive', 'NOUN'),
#  ('in', 'ADP'),
#  ('March', 'NOUN'),
#  ('for', 'ADP'),
#  ('health', 'NOUN'),
#  ('reasons', 'NOUN'),
#  ('.', '.'),
#  ('``', '.'),
#  ('These', 'DET'),
#  ('kids', 'NOUN'),
#  ('broke', 'VERB'),
#  ('my', 'PRON'),
#  ('heart', 'NOUN'),
#  (',', '.'),
#  ("''", '.'),
#  ('she', 'PRON'),
#  ('says', 'VERB'),
#  ('*T*-1', 'X'),
#  ('.', '.'),
#  ('Despite', 'ADP'),
#  ('the', 'DET'),
#  ('enormous', 'ADJ'),
#  ('sums', 'NOUN'),
#  ('of', 'ADP'),
#  ('money', 'NOUN'),
#  ('0', 'X'),
#  ('they', 'PRON'),
#  ("'re", 'VERB'),
#  ('paid', 'VERB'),
#  ('*T*-1', 'X'),
#  ('*-2', 'X'),
#  ('to', 'PRT'),
#  ('stand', 'VERB'),
#  ('up', 'PRT'),
#  ('at', 'ADP'),
#  ('a', 'DET'),
#  ('Japanese', 'ADJ'),
#  ('plate', 'NOUN'),
#  (',', '.'),
#  ('a', 'DET'),
#  ('good', 'ADJ'),
#  ('number', 'NOUN'),
#  ('decide', 'VERB'),
#  ('0', 'X'),
#  ('it', 'PRON'),
#  ("'s", 'VERB'),
#  ('not', 'ADV'),
#  ('worth', 'ADJ'),
#  ('it', 'PRON'),
#  ('and', 'CONJ'),
#  ('run', 'VERB'),
#  ('for', 'ADP'),
#  ('home', 'NOUN'),
#  ('.', '.'),
#  ('Mrs.', 'NOUN'),
#  ('Yeargin', 'NOUN'),
#  ('says', 'VERB'),
#  ('that', 'ADP'),
#  ('she', 'PRON'),
#  ('also', 'ADV'),
#  ('wanted', 'VERB'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('help', 'VERB'),
#  ('*-2', 'X'),
#  ('lift', 'VERB'),
#  ('Greenville', 'NOUN'),
#  ('High', 'NOUN'),
#  ('School', 'NOUN'),
#  ("'s", 'PRT'),
#  ('overall', 'ADJ'),
#  ('test', 'NOUN'),
#  ('scores', 'NOUN'),
#  (',', '.'),
#  ('usually', 'ADV'),
#  ('near', 'ADP'),
#  ('the', 'DET'),
#  ('bottom', 'NOUN'),
#  ('of', 'ADP'),
#  ('14', 'NUM'),
#  ('district', 'NOUN'),
#  ('high', 'ADJ'),
#  ('schools', 'NOUN'),
#  ('in', 'ADP'),
#  ('rankings', 'NOUN'),
#  ('carried', 'VERB'),
#  ('*', 'X'),
#  ('annually', 'ADV'),
#  ('by', 'ADP'),
#  ('local', 'ADJ'),
#  ('newspapers', 'NOUN'),
#  ('.', '.'),
#  ('Many', 'ADJ'),
#  ('of', 'ADP'),
#  ('them', 'PRON'),
#  ('recently', 'ADV'),
#  ('have', 'VERB'),
#  ('been', 'VERB'),
#  ('spending', 'VERB'),
#  ('a', 'DET'),
#  ('lot', 'NOUN'),
#  ('of', 'ADP'),
#  ('money', 'NOUN'),
#  ('on', 'ADP'),
#  ('public', 'ADJ'),
#  ('relations', 'NOUN'),
#  ('and', 'CONJ'),
#  ('advertising', 'NOUN'),
#  ('*-1', 'X'),
#  ('to', 'PRT'),
#  ('improve', 'VERB'),
#  ('their', 'PRON'),
#  ('images', 'NOUN'),
#  (',', '.'),
#  ('but', 'CONJ'),
#  ('they', 'PRON'),
#  ('should', 'VERB'),
#  ('realize', 'VERB'),
#  ('that', 'ADP'),
#  ('the', 'DET'),
#  ('most', 'ADV'),
#  ('important', 'ADJ'),
#  ('thing', 'NOUN'),
#  ('is', 'VERB'),
#  ('real', 'ADJ'),
#  ('change', 'NOUN'),
#  (',', '.'),
#  ('not', 'ADV'),
#  ('*', 'X'),
#  ('changing', 'VERB'),
#  ('people', 'NOUN'),
#  ("'s", 'PRT'),
#  ('perceptions', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('guild', 'NOUN'),
#  ('began', 'VERB'),
#  ('a', 'DET'),
#  ('strike', 'NOUN'),
#  ('against', 'ADP'),
#  ('the', 'DET'),
#  ('TV', 'NOUN'),
#  ('and', 'CONJ'),
#  ('movie', 'NOUN'),
#  ('industry', 'NOUN'),
#  ('in', 'ADP'),
#  ('March', 'NOUN'),
#  ('1988', 'NUM'),
#  ('.', '.'),
#  ('Hadson', 'NOUN'),
#  ('Corp.', 'NOUN'),
#  ('said', 'VERB'),
#  ('0', 'X'),
#  ('it', 'PRON'),
#  ...]

# %%
# tokens 
tokens = [pair[0] for pair in train_tagged_words]
tokens[:10]
# Out:
# ['Modifications',
#  '*ICH*-3',
#  'had',
#  'been',
#  'made',
#  '*-80',
#  'to',
#  'the',
#  'Souper',
#  'Combo']

# %%
# vocabulary
V = set(tokens)
print(len(V))
# Out:
# 11999

# %%
# number of tags
T = set([pair[1] for pair in train_tagged_words])
len(T)
# Out:
# 12

# %%
# Check available tags
print(T)
# Out:
# {'ADP', 'PRON', 'ADV', 'DET', 'CONJ', '.', 'X', 'PRT', 'NOUN', 'VERB', 'ADJ', 'NUM'}

# %%
# Creating matrix for tags and words
t = len(T)
v = len(V)
w_given_t = np.zeros((t, v))

# %% [markdown]
# ### Build the vanilla Viterbi based POS tagger

# %%
# compute word given tag: Emission Probability
def word_given_tag(word, tag, train_bag = train_tagged_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)
    
    return (count_w_given_tag, count_tag)

# %%
def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
            count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
tags_matrix = np.zeros((len(T), len(T)), dtype='float32')
for i, t1 in enumerate(list(T)):
    for j, t2 in enumerate(list(T)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]

# %%
tags_df = pd.DataFrame(tags_matrix, columns = list(T), index=list(T))

# %%
# Viterbi Heuristic
def Viterbi(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
# list of tagged words
test_run_base = [tup for sent in test_set for tup in sent]
#print(test_run_base)
# list of untagged words
test_tagged_words = [tup[0] for tup in test_run_base]
#test_tagged_words

train_tagged_words = [tup for sent in train_set for tup in sent]

# %%
start = time.time()
tagged_seq = Viterbi(test_tagged_words)
end = time.time()
print('Time required for execution:',end - start)
# Out:
# Time required for execution: 1159.7331039905548

# %%
check = list([i for i, j in zip(tagged_seq, test_run_base) if i == j])
len(check)
# Out:
# 4562

# %%
accuracy = len(check)/len(tagged_seq)
accuracy
# Out:
# 0.8908416324936536

# %% [markdown]
# **Vanilla Viterbi is giving around 90 to 91% accuracy

# %% [markdown]
# ### Validation set performance on vanilla Viterbi

# %%
#validation set

validation_tokens
# Out:
# ['Android',
#  'is',
#  'a',
#  'mobile',
#  'operating',
#  'system',
#  'developed',
#  'by',
#  'Google',
#  '.',
#  'Android',
#  'has',
#  'been',
#  'the',
#  'best-selling',
#  'OS',
#  'worldwide',
#  'on',
#  'smartphones',
#  'since',
#  '2011',
#  'and',
#  'on',
#  'tablets',
#  'since',
#  '2013',
#  '.',
#  'Google',
#  'and',
#  'Twitter',
#  'made',
#  'a',
#  'deal',
#  'in',
#  '2015',
#  'that',
#  'gave',
#  'Google',
#  'access',
#  'to',
#  'Twitter',
#  "'s",
#  'firehose',
#  '.',
#  'Twitter',
#  'is',
#  'an',
#  'online',
#  'news',
#  'and',
#  'social',
#  'networking',
#  'service',
#  'on',
#  'which',
#  'users',
#  'post',
#  'and',
#  'interact',
#  'with',
#  'messages',
#  'known',
#  'as',
#  'tweets',
#  '.',
#  'Before',
#  'entering',
#  'politics',
#  ',',
#  'Donald',
#  'Trump',
#  'was',
#  'a',
#  'domineering',
#  'businessman',
#  'and',
#  'a',
#  'television',
#  'personality',
#  '.',
#  'The',
#  '2018',
#  'FIFA',
#  'World',
#  'Cup',
#  'is',
#  'the',
#  '21st',
#  'FIFA',
#  'World',
#  'Cup',
#  ',',
#  'an',
#  'international',
#  'football',
#  'tournament',
#  'contested',
#  'once',
#  'every',
#  'four',
#  'years',
#  '.',
#  'This',
#  'is',
#  'the',
#  'first',
#  'World',
#  'Cup',
#  'to',
#  'be',
#  'held',
#  'in',
#  'Eastern',
#  'Europe',
#  'and',
#  'the',
#  '11th',
#  'time',
#  'that',
#  'it',
#  'has',
#  'been',
#  'held',
#  'in',
#  'Europe',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'cheapest',
#  'round',
#  'trips',
#  'from',
#  'Dallas',
#  'to',
#  'Atlanta',
#  'I',
#  'would',
#  'like',
#  'to',
#  'see',
#  'flights',
#  'from',
#  'Denver',
#  'to',
#  'Philadelphia',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'price',
#  'of',
#  'the',
#  'flights',
#  'leaving',
#  'Atlanta',
#  'at',
#  'about',
#  '3',
#  'in',
#  'the',
#  'afternoon',
#  'and',
#  'arriving',
#  'in',
#  'San',
#  'Francisco',
#  '.',
#  'NASA',
#  'invited',
#  'social',
#  'media',
#  'users',
#  'to',
#  'experience',
#  'the',
#  'launch',
#  'of',
#  'ICESAT-2',
#  'Satellite',
#  '.']

# %%
#Accuracy check on validation set
start = time.time()
tagged_seq_validation = Viterbi(validation_tokens)
end = time.time()
print('Time required for execution:',end - start)
# Out:
# Time required for execution: 43.81310415267944

# %%
tagged_seq_validation
# Out:
# [('Android', 'ADP'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google', 'ADP'),
#  ('.', '.'),
#  ('Android', 'ADP'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', 'ADP'),
#  ('worldwide', 'ADP'),
#  ('on', 'ADP'),
#  ('smartphones', 'ADP'),
#  ('since', 'ADP'),
#  ('2011', 'ADP'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013', 'ADP'),
#  ('.', '.'),
#  ('Google', 'ADP'),
#  ('and', 'CONJ'),
#  ('Twitter', 'ADP'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'ADP'),
#  ('that', 'DET'),
#  ('gave', 'VERB'),
#  ('Google', 'ADP'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', 'ADP'),
#  ("'s", 'PRT'),
#  ('firehose', 'ADP'),
#  ('.', '.'),
#  ('Twitter', 'ADP'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'ADP'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'ADP'),
#  ('with', 'ADP'),
#  ('messages', 'ADP'),
#  ('known', 'ADJ'),
#  ('as', 'ADP'),
#  ('tweets', 'ADP'),
#  ('.', '.'),
#  ('Before', 'ADP'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('Donald', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'ADP'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality', 'ADP'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('2018', 'ADP'),
#  ('FIFA', 'ADP'),
#  ('World', 'NOUN'),
#  ('Cup', 'ADP'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'ADP'),
#  ('FIFA', 'ADP'),
#  ('World', 'NOUN'),
#  ('Cup', 'ADP'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'ADP'),
#  ('contested', 'ADP'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years', 'NOUN'),
#  ('.', '.'),
#  ('This', 'DET'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('World', 'NOUN'),
#  ('Cup', 'ADP'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Eastern', 'NOUN'),
#  ('Europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'ADJ'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Europe', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'ADP'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'ADP'),
#  ('from', 'ADP'),
#  ('Dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('Atlanta', 'NOUN'),
#  ('I', 'PRON'),
#  ('would', 'VERB'),
#  ('like', 'ADP'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('Denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('Philadelphia', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'ADP'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('Atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADP'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'ADP'),
#  ('in', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('.', '.'),
#  ('NASA', 'ADP'),
#  ('invited', 'ADP'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'NOUN'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('ICESAT-2', 'ADP'),
#  ('Satellite', 'ADP'),
#  ('.', '.')]

# %% [markdown]
# ### Observations on validation set

# %% [markdown]
# -- Google, Android, Twitter etc are getting identified as ADP instead of NOUN, this is because unknown words are getting tagged by default to ADP (first tag)
#
# -- Numbers are not tagged correctly

# %% [markdown]
# ### Check incorrect tags in test set to identify modification areas

# %%
incorrect_tagged_cases = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [[('will', 'VERB'), (('rule', 'NOUN'), ('rule', 'VERB'))],
#  [('Pat', 'NOUN'), (("D'Amico", 'ADP'), ("D'Amico", 'NOUN'))],
#  [('were', 'VERB'), (('slow', 'VERB'), ('slow', 'ADJ'))],
#  [('to', 'PRT'), (('computerize', 'ADP'), ('computerize', 'VERB'))],
#  [("n't", 'ADV'), (('target', 'NOUN'), ('target', 'VERB'))],
#  [('market', 'NOUN'), (('niches', 'ADP'), ('niches', 'NOUN'))],
#  [('that', 'DET'), (('*T*-199', 'ADP'), ('*T*-199', 'X'))],
#  [('Education', 'NOUN'), (('rates', 'NOUN'), ('rates', 'VERB'))],
#  [('its', 'PRON'), (('study', 'VERB'), ('study', 'NOUN'))],
#  [('to', 'PRT'), (('waive', 'ADP'), ('waive', 'VERB'))],
#  [('its', 'PRON'), (('protective', 'ADP'), ('protective', 'ADJ'))],
#  [('``', '.'), (('golden', 'ADP'), ('golden', 'ADJ'))],
#  [('Italian', 'ADJ'), (('biscuit', 'ADP'), ('biscuit', 'NOUN'))],
#  [('D.', 'NOUN'), (('Lazzaroni', 'ADP'), ('Lazzaroni', 'NOUN'))],
#  [('by', 'ADP'), (('overproduction', 'ADP'), ('overproduction', 'NOUN'))],
#  [(',', '.'), (('so', 'ADV'), ('so', 'ADP'))],
#  [('the', 'DET'), (('lieutenant', 'ADP'), ('lieutenant', 'NOUN'))],
#  [('Stanley', 'NOUN'), (('Fishman', 'ADP'), ('Fishman', 'NOUN'))],
#  [(',', '.'), (('Longwood', 'ADP'), ('Longwood', 'NOUN'))],
#  [('Harold', 'NOUN'), (('Floyd', 'ADP'), ('Floyd', 'NOUN'))],
#  [(';', '.'), (('Amin', 'ADP'), ('Amin', 'NOUN'))],
#  [('Amin', 'NOUN'), (('Jalaalwalikraam', 'ADP'), ('Jalaalwalikraam', 'NOUN'))],
#  [(',', '.'), (('Glenham', 'ADP'), ('Glenham', 'NOUN'))],
#  [('F.', 'NOUN'), (('Knapp', 'ADP'), ('Knapp', 'NOUN'))],
#  [(';', '.'), (('Deborah', 'ADP'), ('Deborah', 'NOUN'))],
#  [('Deborah', 'NOUN'), (('Renee', 'ADP'), ('Renee', 'NOUN'))],
#  [('Joseph', 'NOUN'), (('Francis', 'ADP'), ('Francis', 'NOUN'))],
#  [('Francis', 'NOUN'), (('Muscolina', 'ADP'), ('Muscolina', 'NOUN'))],
#  [(',', '.'), (('Palisades', 'ADP'), ('Palisades', 'NOUN'))],
#  [('C.', 'NOUN'), (('Najarian', 'ADP'), ('Najarian', 'NOUN'))],
#  [(',', '.'), (('Minn.', 'ADP'), ('Minn.', 'NOUN'))],
#  [('Robert', 'NOUN'), (('Norwick', 'ADP'), ('Norwick', 'NOUN'))],
#  [(',', '.'), (('Nesconset', 'ADP'), ('Nesconset', 'NOUN'))],
#  [('their', 'PRON'), (('views', 'VERB'), ('views', 'NOUN'))],
#  [('.', '.'), (('IRAs', 'ADP'), ('IRAs', 'NOUN'))],
#  [('.', '.'), (('Output', 'ADP'), ('Output', 'NOUN'))],
#  [('be', 'VERB'), (('gradually', 'ADP'), ('gradually', 'ADV'))],
#  [('it', 'PRON'), (('reaches', 'ADP'), ('reaches', 'VERB'))],
#  [('.', '.'), (('Pakistan', 'ADP'), ('Pakistan', 'NOUN'))],
#  [("'s", 'PRT'), (('Bhutto', 'ADP'), ('Bhutto', 'NOUN'))],
#  [('Bhutto', 'NOUN'), (('defeated', 'ADP'), ('defeated', 'VERB'))],
#  [('first', 'ADJ'), (('no-confidence', 'ADP'), ('no-confidence', 'NOUN'))],
#  [("'s", 'PRT'), (('42-year', 'ADP'), ('42-year', 'ADJ'))],
#  [('vote', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('brought', 'VERB'), (('down', 'ADV'), ('down', 'PRT'))],
#  [('her', 'PRON'), (('11-month-old', 'ADP'), ('11-month-old', 'ADJ'))],
#  [('*-1', 'X'), (('Absorbed', 'ADP'), ('Absorbed', 'VERB'))],
#  [('*', 'X'), (('doling', 'ADP'), ('doling', 'VERB'))],
#  [('doling', 'VERB'), (('out', 'ADP'), ('out', 'PRT'))],
#  [("''", '.'), (('tidbits', 'ADP'), ('tidbits', 'NOUN'))],
#  [('authors', 'NOUN'), (('gloss', 'ADP'), ('gloss', 'VERB'))],
#  [('the', 'DET'), (('root', 'ADP'), ('root', 'NOUN'))],
#  [('-LRB-', '.'), (('A', 'DET'), ('A', 'NOUN'))],
#  [('whose', 'PRON'), (('auspices', 'ADP'), ('auspices', 'NOUN'))],
#  [('.', '.'), (('South', 'NOUN'), ('South', 'ADJ'))],
#  [('South', 'ADJ'), (('African', 'NOUN'), ('African', 'ADJ'))],
#  [('.', '.'), (('Items', 'ADP'), ('Items', 'NOUN'))],
#  [('supply', 'NOUN'), (('numbered', 'ADP'), ('numbered', 'VERB'))],
#  [('only', 'ADV'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('one', 'NUM'), (('newcomer', 'ADP'), ('newcomer', 'NOUN'))],
#  [('milk', 'NOUN'), (('powder', 'ADP'), ('powder', 'NOUN'))],
#  [('share', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-119', 'ADP'), ('*T*-119', 'X'))],
#  [('*T*-119', 'X'), (('expires', 'ADP'), ('expires', 'VERB'))],
#  [('payouts', 'NOUN'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('to', 'PRT'), (('realestate', 'ADP'), ('realestate', 'VERB'))],
#  [('good', 'ADJ'), (('will', 'VERB'), ('will', 'NOUN'))],
#  [('-LRB-', '.'), (('Topix', 'ADP'), ('Topix', 'NOUN'))],
#  [('gained', 'VERB'), (('16.05', 'ADP'), ('16.05', 'NUM'))],
#  [('down', 'ADV'), (('1.46', 'ADP'), ('1.46', 'NUM'))],
#  [('or', 'CONJ'), (('0.05', 'ADP'), ('0.05', 'NUM'))],
#  [('at', 'ADP'), (('2691.19', 'ADP'), ('2691.19', 'NUM'))],
#  [('to', 'PRT'), (('imagine', 'ADP'), ('imagine', 'VERB'))],
#  [('Japan', 'NOUN'), (('racing', 'ADP'), ('racing', 'VERB'))],
#  [('introduce', 'VERB'), (('Chicago-style', 'ADP'), ('Chicago-style', 'ADJ'))],
#  [('an', 'DET'), (('arbitrager', 'ADP'), ('arbitrager', 'NOUN'))],
#  [('passion', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-227', 'ADP'), ('*T*-227', 'X'))],
#  [('usually', 'ADV'), (('stays', 'ADP'), ('stays', 'VERB'))],
#  [('.', '.'), (('ABORTION', 'ADP'), ('ABORTION', 'NOUN'))],
#  [('ABORTION', 'NOUN'), (('RULING', 'ADP'), ('RULING', 'NOUN'))],
#  [('RULING', 'NOUN'), (('UPHELD', 'ADP'), ('UPHELD', 'VERB'))],
#  [('be', 'VERB'), (('equipped', 'ADP'), ('equipped', 'VERB'))],
#  [('equipped', 'VERB'), (('*-90', 'ADP'), ('*-90', 'X'))],
#  [('same', 'ADJ'), (('front-seat', 'ADP'), ('front-seat', 'NOUN'))],
#  [('front-seat', 'NOUN'), (('headrests', 'ADP'), ('headrests', 'NOUN'))],
#  [('required', 'VERB'), (('*-91', 'ADP'), ('*-91', 'X'))],
#  [('100', 'NUM'), (('16\\/32', 'ADP'), ('16\\/32', 'NUM'))],
#  [(',', '.'), (('Ind.', 'ADP'), ('Ind.', 'NOUN'))],
#  [('replace', 'VERB'), (('arched', 'ADP'), ('arched', 'ADJ'))],
#  [('the', 'DET'), (('G', 'ADP'), ('G', 'NOUN'))],
#  [('Cosby', 'NOUN'), (('Show', 'ADP'), ('Show', 'NOUN'))],
#  [('turned', 'VERB'), (('around', 'ADP'), ('around', 'PRT'))],
#  [('the', 'DET'), (('Huxtable', 'ADP'), ('Huxtable', 'NOUN'))],
#  [('of', 'ADP'), (('viewers', 'ADP'), ('viewers', 'NOUN'))],
#  [('viewers', 'NOUN'), (('laughing', 'ADJ'), ('laughing', 'VERB'))],
#  [('announcer', 'NOUN'), (('interjects', 'ADP'), ('interjects', 'VERB'))],
#  [('be', 'VERB'), (('interrogated', 'ADP'), ('interrogated', 'VERB'))],
#  [('accused', 'VERB'), (('rapists', 'ADP'), ('rapists', 'NOUN'))],
#  [(',', '.'), (('Conn.based', 'ADP'), ('Conn.based', 'ADJ'))],
#  [('was', 'VERB'), (('magnified', 'ADP'), ('magnified', 'VERB'))],
#  [('by', 'ADP'), (('nonrecurring', 'ADP'), ('nonrecurring', 'VERB'))],
#  [('$', '.'), (('8.2', 'ADP'), ('8.2', 'NUM'))],
#  [('in', 'ADP'), (('asset-valuation', 'ADP'), ('asset-valuation', 'NOUN'))],
#  [('asset-valuation', 'NOUN'),
#   (('adjustments', 'ADP'), ('adjustments', 'NOUN'))],
#  [('adjustments', 'NOUN'), (('that', 'DET'), ('that', 'ADP'))],
#  [("n't", 'ADV'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('as', 'ADV'), (('troublesome', 'ADP'), ('troublesome', 'ADJ'))],
#  [('*-2', 'X'), (('Given', 'ADP'), ('Given', 'VERB'))],
#  [('*-3', 'X'), (('that', 'ADP'), ('that', 'DET'))],
#  [('not', 'ADV'), (('overpaying', 'ADP'), ('overpaying', 'VERB'))],
#  [('of', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('have', 'VERB'), (('crossed', 'ADP'), ('crossed', 'VERB'))],
#  [('*-1', 'X'), (('gauging', 'ADP'), ('gauging', 'VERB'))],
#  [('In', 'ADP'), (('early', 'ADJ'), ('early', 'ADV'))],
#  [('fell', 'VERB'), (('63.79', 'ADP'), ('63.79', 'NUM'))],
#  [('to', 'PRT'), (('35500.64', 'ADP'), ('35500.64', 'NUM'))],
#  [('The', 'DET'), (('Contra', 'ADP'), ('Contra', 'NOUN'))],
#  [('military', 'ADJ'), (('command', 'VERB'), ('command', 'NOUN'))],
#  [('from', 'ADP'), (('Honduras', 'ADP'), ('Honduras', 'NOUN'))],
#  [('0', 'X'), (('Sandinista', 'ADP'), ('Sandinista', 'NOUN'))],
#  [('major', 'ADJ'), (('offensive', 'ADP'), ('offensive', 'NOUN'))],
#  [('the', 'DET'), (('rebel', 'ADP'), ('rebel', 'NOUN'))],
#  [('Only', 'ADV'), (('57.6', 'ADP'), ('57.6', 'NUM'))],
#  [('New', 'NOUN'), (('Yorkers', 'ADP'), ('Yorkers', 'NOUN'))],
#  [('Yorkers', 'NOUN'), (('watch', 'NOUN'), ('watch', 'VERB'))],
#  [('lowest', 'ADJ'), (('viewership', 'ADP'), ('viewership', 'NOUN'))],
#  [('by', 'ADP'), (('Impact', 'ADP'), ('Impact', 'NOUN'))],
#  [(',', '.'), (('Columbus', 'ADP'), ('Columbus', 'NOUN'))],
#  [('companies', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('have', 'VERB'), (('diversified', 'ADJ'), ('diversified', 'VERB'))],
#  [('all', 'DET'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('impressive', 'ADP'), ('impressive', 'ADJ'))],
#  [('who', 'PRON'), (('*T*-182', 'ADP'), ('*T*-182', 'X'))],
#  [('to', 'PRT'), (('combat', 'ADP'), ('combat', 'VERB'))],
#  [('*T*-51', 'X'), (('import', 'NOUN'), ('import', 'VERB'))],
#  [('probably', 'ADV'), (('worth', 'ADJ'), ('worth', 'ADP'))],
#  [('funds', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('markets', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('gaining', 'VERB'), (('1,200', 'ADP'), ('1,200', 'NUM'))],
#  [('Jack', 'NOUN'), (('Mogavero', 'ADP'), ('Mogavero', 'NOUN'))],
#  [(',', '.'), (('Piscataway', 'ADP'), ('Piscataway', 'NOUN'))],
#  [('an', 'DET'), (('eight-count', 'ADP'), ('eight-count', 'ADJ'))],
#  [('eight-count', 'ADJ'), (('indictment', 'ADP'), ('indictment', 'NOUN'))],
#  [('its', 'PRON'), (('Vice', 'ADP'), ('Vice', 'NOUN'))],
#  [('T.', 'NOUN'), (('Sherwin', 'ADP'), ('Sherwin', 'NOUN'))],
#  [('to', 'PRT'), (('manipulate', 'ADP'), ('manipulate', 'VERB'))],
#  [('Union', 'NOUN'), (('Carbide', 'ADP'), ('Carbide', 'NOUN'))],
#  [("'s", 'PRT'), (('planned', 'VERB'), ('planned', 'ADJ'))],
#  [(',', '.'), (('gilt', 'ADP'), ('gilt', 'ADJ'))],
#  [('plunged', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('*-1', 'X'), (('recovering', 'ADP'), ('recovering', 'VERB'))],
#  [('The', 'DET'), (('parishioners', 'ADP'), ('parishioners', 'NOUN'))],
#  [('All', 'DET'), (('Angels', 'ADP'), ('Angels', 'NOUN'))],
#  [('to', 'PRT'), (('chat', 'ADP'), ('chat', 'VERB'))],
#  [('The', 'DET'), (('low-ball', 'ADP'), ('low-ball', 'ADJ'))],
#  [('corporate', 'ADJ'), (('purchasing', 'NOUN'), ('purchasing', 'VERB'))],
#  [('remains', 'VERB'), (('confident', 'ADP'), ('confident', 'ADJ'))],
#  [('future', 'ADJ'),
#   (('creditworthiness', 'ADP'), ('creditworthiness', 'NOUN'))],
#  [('Gulf', 'NOUN'), (('rebuffed', 'ADP'), ('rebuffed', 'VERB'))],
#  [('would', 'VERB'), (('study', 'NOUN'), ('study', 'VERB'))],
#  [('who', 'PRON'), (('*T*-169', 'ADP'), ('*T*-169', 'X'))],
#  [('*T*-169', 'X'), (('buy', 'NOUN'), ('buy', 'VERB'))],
#  [('also', 'ADV'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('more', 'ADV'), (('knowledgeable', 'ADP'), ('knowledgeable', 'ADJ'))],
#  [('years', 'NOUN'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('an', 'DET'), (('implicit', 'ADP'), ('implicit', 'ADJ'))],
#  [('the', 'DET'), (('Japanese', 'ADJ'), ('Japanese', 'NOUN'))],
#  [('.', '.'), (('Yet', 'CONJ'), ('Yet', 'ADV'))],
#  [('of', 'ADP'), (('Wilmington', 'ADP'), ('Wilmington', 'NOUN'))],
#  [('of', 'ADP'), (('neoprene', 'ADP'), ('neoprene', 'NOUN'))],
#  [('synthetic', 'ADJ'), (('rubber', 'ADP'), ('rubber', 'NOUN'))],
#  [(',', '.'), (('supreme', 'ADP'), ('supreme', 'NOUN'))],
#  [(',', '.'), (('Deng', 'ADP'), ('Deng', 'NOUN'))],
#  [('Deng', 'NOUN'), (('Xiaoping', 'ADP'), ('Xiaoping', 'NOUN'))],
#  [('*', 'X'), (('Frankly', 'ADP'), ('Frankly', 'ADV'))],
#  [('Frankly', 'ADV'), (('speaking', 'ADP'), ('speaking', 'VERB'))],
#  [('involved', 'VERB'), (('*-146', 'ADP'), ('*-146', 'X'))],
#  [('too', 'ADV'), (('deeply', 'ADP'), ('deeply', 'ADV'))],
#  [('and', 'CONJ'),
#   (('counterrevolutionary', 'ADP'), ('counterrevolutionary', 'ADJ'))],
#  [('counterrevolutionary', 'ADJ'),
#   (('rebellion', 'ADP'), ('rebellion', 'NOUN'))],
#  [('which', 'DET'), (('*T*-243', 'ADP'), ('*T*-243', 'X'))],
#  [('not', 'ADV'), (('long', 'ADJ'), ('long', 'ADV'))],
#  [('long', 'ADV'), (('ago', 'ADP'), ('ago', 'ADV'))],
#  [('economists', 'NOUN'), (('forecast', 'NOUN'), ('forecast', 'VERB'))],
#  [('%', 'NOUN'), (('rise', 'VERB'), ('rise', 'NOUN'))],
#  [('to', 'PRT'), (('5.4', 'ADP'), ('5.4', 'NUM'))],
#  [('A', 'DET'), (('disaffected', 'ADP'), ('disaffected', 'ADJ'))],
#  [(',', '.'), (('hard-drinking', 'ADP'), ('hard-drinking', 'ADJ'))],
#  [(',', '.'), (('nearly-30', 'ADP'), ('nearly-30', 'ADJ'))],
#  [('hero', 'NOUN'), (('sets', 'NOUN'), ('sets', 'VERB'))],
#  [('for', 'ADP'), (('snow', 'ADP'), ('snow', 'NOUN'))],
#  [('in', 'ADP'), (('search', 'ADP'), ('search', 'NOUN'))],
#  [('an', 'DET'), (('elusive', 'ADP'), ('elusive', 'ADJ'))],
#  [('elusive', 'ADJ'), (('sheep', 'ADP'), ('sheep', 'NOUN'))],
#  [('its', 'PRON'), (('back', 'ADV'), ('back', 'NOUN'))],
#  [('the', 'DET'), (('behest', 'ADP'), ('behest', 'NOUN'))],
#  [('a', 'DET'), (('sinister', 'ADP'), ('sinister', 'ADJ'))],
#  [(',', '.'), (('erudite', 'ADP'), ('erudite', 'ADJ'))],
#  [('erudite', 'ADJ'), (('mobster', 'ADP'), ('mobster', 'NOUN'))],
#  [('But', 'CONJ'), (('C.J.B.', 'ADP'), ('C.J.B.', 'NOUN'))],
#  [('a', 'DET'), (('nearby', 'ADV'), ('nearby', 'ADJ'))],
#  [('the', 'DET'), (('stairs', 'ADP'), ('stairs', 'NOUN'))],
#  [('tower', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('located', 'VERB'), (('*-138', 'ADP'), ('*-138', 'X'))],
#  [('the', 'DET'), (('altar', 'ADP'), ('altar', 'NOUN'))],
#  [('the', 'DET'), (('right', 'NOUN'), ('right', 'ADJ'))],
#  [('this', 'DET'), (('minute', 'ADJ'), ('minute', 'NOUN'))],
#  [('company', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-146', 'ADP'), ('*T*-146', 'X'))],
#  [('Michael', 'NOUN'), (('Stark', 'ADP'), ('Stark', 'NOUN'))],
#  [('at', 'ADP'), (('Robertson', 'ADP'), ('Robertson', 'NOUN'))],
#  [(',', '.'), (('Stephens', 'ADP'), ('Stephens', 'NOUN'))],
#  [('12-point', 'ADJ'),
#   (('circuit-breaker', 'ADP'), ('circuit-breaker', 'NOUN'))],
#  [('circuit-breaker', 'NOUN'),
#   (('aggravated', 'ADP'), ('aggravated', 'VERB'))],
#  [('*-1', 'X'), (('directing', 'ADP'), ('directing', 'VERB'))],
#  [('additional', 'ADJ'), (('selling', 'NOUN'), ('selling', 'VERB'))],
#  [('Much', 'ADV'), (('less', 'ADJ'), ('less', 'ADV'))],
#  [('-LCB-', '.'), (('index-arbitrage', 'ADJ'), ('index-arbitrage', 'NOUN'))],
#  [('done', 'VERB'), (('*-161', 'ADP'), ('*-161', 'X'))],
#  [('Richard', 'NOUN'), (('Barfield', 'ADP'), ('Barfield', 'NOUN'))],
#  [('Life', 'NOUN'), (('Assurance', 'ADP'), ('Assurance', 'NOUN'))],
#  [('which', 'DET'), (('*T*-258', 'ADP'), ('*T*-258', 'X'))],
#  [('*T*-258', 'X'), (('manages', 'ADP'), ('manages', 'VERB'))],
#  [('$', '.'), (('23.72', 'ADP'), ('23.72', 'NUM'))],
#  [('so', 'ADV'), (('broadly', 'ADP'), ('broadly', 'ADV'))],
#  [('broadly', 'ADV'), (('construed', 'ADP'), ('construed', 'VERB'))],
#  [('would', 'VERB'), (('emasculate', 'ADP'), ('emasculate', 'VERB'))],
#  [('and', 'CONJ'), (('swallow', 'ADP'), ('swallow', 'VERB'))],
#  [('are', 'VERB'), (('forcing', 'ADJ'), ('forcing', 'VERB'))],
#  [('overseas', 'ADJ'), (('sites', 'ADP'), ('sites', 'NOUN'))],
#  [('for', 'ADP'), (('labor-intensive', 'ADP'), ('labor-intensive', 'ADJ'))],
#  [('``', '.'), (('excess', 'NOUN'), ('excess', 'ADJ'))],
#  [('what', 'PRON'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('the', 'DET'), (('earliest', 'ADP'), ('earliest', 'ADJ'))],
#  [('all', 'DET'), (('pension-fund', 'ADP'), ('pension-fund', 'ADJ'))],
#  [('England', 'NOUN'), (('steadily', 'ADP'), ('steadily', 'ADV'))],
#  [('steadily', 'ADV'), (('dwindling', 'ADP'), ('dwindling', 'VERB'))],
#  [(',', '.'), (('strong-willed', 'ADP'), ('strong-willed', 'ADJ'))],
#  [('are', 'VERB'), (('pressing', 'ADP'), ('pressing', 'VERB'))],
#  [('equally', 'ADV'), (('strong-willed', 'ADP'), ('strong-willed', 'ADJ'))],
#  [('often', 'ADV'), (('non-religious', 'ADP'), ('non-religious', 'ADJ'))],
#  [('another', 'DET'), (('drag-down', 'ADP'), ('drag-down', 'ADJ'))],
#  [('a', 'DET'), (('chaotic', 'ADP'), ('chaotic', 'ADJ'))],
#  [('a', 'DET'), (('trap', 'ADP'), ('trap', 'NOUN'))],
#  [('for', 'ADP'), (('unwary', 'ADP'), ('unwary', 'ADJ'))],
#  [('senior', 'ADJ'), (('quantitative', 'ADP'), ('quantitative', 'ADJ'))],
#  [('an', 'DET'), (('interior', 'ADP'), ('interior', 'ADJ'))],
#  [('interior', 'ADJ'), (('decorator', 'ADP'), ('decorator', 'NOUN'))],
#  [('things', 'NOUN'), (('spook', 'ADP'), ('spook', 'VERB'))],
#  [('a', 'DET'), (('sprawling', 'ADP'), ('sprawling', 'ADJ'))],
#  [(',', '.'), (('balkanized', 'ADP'), ('balkanized', 'ADJ'))],
#  [('the', 'DET'), (('mammoth', 'ADP'), ('mammoth', 'ADJ'))],
#  [('then', 'ADV'), (('target', 'NOUN'), ('target', 'VERB'))],
#  [('James', 'NOUN'), (('Bellows', 'ADP'), ('Bellows', 'NOUN'))],
#  [('*T*-48', 'X'), (('brightened', 'ADP'), ('brightened', 'VERB'))],
#  [('.', '.'), (('Image', 'ADP'), ('Image', 'NOUN'))],
#  [('what', 'PRON'), (('*T*-170', 'ADP'), ('*T*-170', 'X'))],
#  [('what', 'PRON'), (('*T*-171', 'ADP'), ('*T*-171', 'X'))],
#  [('forced', 'VERB'), (('*-100', 'ADP'), ('*-100', 'X'))],
#  [('a', 'DET'), (('Delaware', 'ADP'), ('Delaware', 'NOUN'))],
#  [('of', 'ADP'), (('Dunkin', 'ADP'), ('Dunkin', 'NOUN'))],
#  [('ownership', 'NOUN'), (('plans', 'VERB'), ('plans', 'NOUN'))],
#  [('to', 'PRT'), (('deter', 'ADP'), ('deter', 'VERB'))],
#  [('is', 'VERB'), (('unworkable', 'ADP'), ('unworkable', 'ADJ'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('branch', 'NOUN'), (('unfunded', 'ADP'), ('unfunded', 'ADJ'))],
#  [('could', 'VERB'), (('sign', 'NOUN'), ('sign', 'VERB'))],
#  [('and', 'CONJ'), (('assert', 'ADP'), ('assert', 'VERB'))],
#  [('rider', 'NOUN'), (('restricting', 'ADP'), ('restricting', 'VERB'))],
#  [('the', 'DET'), (('context', 'ADP'), ('context', 'NOUN'))],
#  [('is', 'VERB'), (('characterized', 'ADP'), ('characterized', 'VERB'))],
#  [('to', 'PRT'), (('excise', 'ADJ'), ('excise', 'VERB'))],
#  [('bill', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('are', 'VERB'), (('objectionable', 'ADP'), ('objectionable', 'ADJ'))],
#  [('they', 'PRON'), (('conflict', 'ADP'), ('conflict', 'VERB'))],
#  [('to', 'PRT'), (('clear', 'ADJ'), ('clear', 'VERB'))],
#  [('a', 'DET'), (('sell-off', 'ADP'), ('sell-off', 'NOUN'))],
#  [('.', '.'), (('Factories', 'ADP'), ('Factories', 'NOUN'))],
#  [('Factories', 'NOUN'), (('booked', 'ADP'), ('booked', 'VERB'))],
#  [('$', '.'), (('236.74', 'ADP'), ('236.74', 'NUM'))],
#  [('$', '.'), (('236.79', 'ADP'), ('236.79', 'NUM'))],
#  [('center', 'NOUN'), (('commercial', 'NOUN'), ('commercial', 'ADJ'))],
#  [('Bush', 'NOUN'), (('distasteful', 'ADP'), ('distasteful', 'ADJ'))],
#  [('even', 'ADV'), (('more', 'ADJ'), ('more', 'ADV'))],
#  [('more', 'ADV'), (('newsworthy', 'ADP'), ('newsworthy', 'ADJ'))],
#  [('The', 'DET'), (('Chinese', 'ADJ'), ('Chinese', 'NOUN'))],
#  [('equally', 'ADV'), (('undiplomatic', 'ADP'), ('undiplomatic', 'ADJ'))],
#  [('undiplomatic', 'ADJ'), (('fashion', 'ADP'), ('fashion', 'NOUN'))],
#  [('gave', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('You', 'PRON'), (('dismiss', 'ADP'), ('dismiss', 'VERB'))],
#  [('``', '.'), (('sentimental', 'ADP'), ('sentimental', 'ADJ'))],
#  [('federal', 'ADJ'),
#   (('housing-assistance', 'ADP'), ('housing-assistance', 'ADJ'))],
#  [('women', 'NOUN'), (('sleeping', 'ADP'), ('sleeping', 'VERB'))],
#  [('the', 'DET'), (('Reagan-Bush', 'ADP'), ('Reagan-Bush', 'ADJ'))],
#  [('Their', 'PRON'), (('report', 'VERB'), ('report', 'NOUN'))],
#  [('the', 'DET'), (('journal', 'ADP'), ('journal', 'NOUN'))],
#  [('journal', 'NOUN'), (('Nature', 'ADP'), ('Nature', 'NOUN'))],
#  [('numerous', 'ADJ'), (('occurrences', 'ADP'), ('occurrences', 'NOUN'))],
#  [('teacher', 'NOUN'), (('help', 'VERB'), ('help', 'NOUN'))],
#  [('is', 'VERB'), (('revising', 'ADP'), ('revising', 'VERB'))],
#  [('worries', 'VERB'), (('credit-rating', 'ADP'), ('credit-rating', 'NOUN'))],
#  [('and', 'CONJ'), (('that', 'DET'), ('that', 'ADP'))],
#  [('The', 'DET'), (('forthcoming', 'ADP'), ('forthcoming', 'ADJ'))],
#  [('a', 'DET'), (('10-year', 'ADJ'), ('10-year', 'NUM'))],
#  [('government', 'NOUN'),
#   (('yen-denominated', 'ADP'), ('yen-denominated', 'ADJ'))],
#  [('at', 'ADP'), (('about', 'ADP'), ('about', 'ADV'))],
#  [('investors', 'NOUN'), (('redeeming', 'ADP'), ('redeeming', 'VERB'))],
#  [('includes', 'VERB'), (('pretax', 'ADJ'), ('pretax', 'NOUN'))],
#  [('while', 'ADP'), (('like', 'ADP'), ('like', 'ADJ'))],
#  [('$', '.'), (('14.75', 'ADP'), ('14.75', 'NUM'))],
#  [('the', 'DET'), (('most', 'ADJ'), ('most', 'ADV'))],
#  [('$', '.'), (('57.7', 'ADP'), ('57.7', 'NUM'))],
#  [('ads', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('team', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('Mercury', 'NOUN'), (('Sable', 'ADP'), ('Sable', 'NOUN'))],
#  [('retired', 'VERB'), (('early', 'ADJ'), ('early', 'ADV'))],
#  [('*-2', 'X'), (('experiencing', 'ADP'), ('experiencing', 'VERB'))],
#  [('be', 'VERB'), (('milked', 'ADP'), ('milked', 'VERB'))],
#  [('milked', 'VERB'), (('*-117', 'ADP'), ('*-117', 'X'))],
#  [(',', '.'), (('as', 'ADP'), ('as', 'ADV'))],
#  [('the', 'DET'), (('principal', 'NOUN'), ('principal', 'ADJ'))],
#  [('principal', 'ADJ'), (('fights', 'ADP'), ('fights', 'NOUN'))],
#  [('makes', 'VERB'), (('rechargeable', 'ADP'), ('rechargeable', 'ADJ'))],
#  [('nickel', 'NOUN'), (('cadmium', 'ADP'), ('cadmium', 'NOUN'))],
#  [('and', 'CONJ'), (('carbon', 'ADP'), ('carbon', 'NOUN'))],
#  [('carbon', 'NOUN'), (('zinc', 'ADP'), ('zinc', 'NOUN'))],
#  [('bad', 'ADJ'), (('movies', 'ADP'), ('movies', 'NOUN'))],
#  [('Gregory', 'NOUN'), (('Peck', 'ADP'), ('Peck', 'NOUN'))],
#  [('a', 'DET'), (('marvelously', 'ADP'), ('marvelously', 'ADV'))],
#  [('marvelously', 'ADV'), (('loose', 'ADP'), ('loose', 'ADJ'))],
#  [('and', 'CONJ'), (('energetic', 'ADP'), ('energetic', 'ADJ'))],
#  [('energetic', 'ADJ'), (('portrayal', 'ADP'), ('portrayal', 'NOUN'))],
#  [('.', '.'), (('Test-preparation', 'ADP'), ('Test-preparation', 'ADJ'))],
#  [('publishing', 'VERB'), (('subindustry', 'ADP'), ('subindustry', 'NOUN'))],
#  [('major', 'ADJ'), (('grower', 'ADP'), ('grower', 'NOUN'))],
#  [('will', 'VERB'), (('climb', 'ADP'), ('climb', 'VERB'))],
#  [('from', 'ADP'), (('566.54', 'ADP'), ('566.54', 'NUM'))],
#  [('was', 'VERB'), (('forecast', 'NOUN'), ('forecast', 'VERB'))],
#  [('from', 'ADP'), (('28.53', 'ADP'), ('28.53', 'NUM'))],
#  [('Andrew', 'NOUN'), (('Derel', 'ADP'), ('Derel', 'NOUN'))],
#  [('Derel', 'NOUN'), (('Adams', 'ADP'), ('Adams', 'NOUN'))],
#  [(',', '.'), (('Killeen', 'ADP'), ('Killeen', 'NOUN'))],
#  [('John', 'NOUN'), (('Francis', 'ADP'), ('Francis', 'NOUN'))],
#  [('Francis', 'NOUN'), (('Angier', 'ADP'), ('Angier', 'NOUN'))],
#  [(',', '.'), (('Reddington', 'ADP'), ('Reddington', 'NOUN'))],
#  [('Reddington', 'NOUN'), (('Shores', 'ADP'), ('Shores', 'NOUN'))],
#  [(',', '.'), (('Arlington', 'ADP'), ('Arlington', 'NOUN'))],
#  [('William', 'NOUN'), (('Stirlen', 'ADP'), ('Stirlen', 'NOUN'))],
#  [(',', '.'), (('Arlington', 'ADP'), ('Arlington', 'NOUN'))],
#  [('W.', 'NOUN'), (('Bonnell', 'ADP'), ('Bonnell', 'NOUN'))],
#  [('J.', 'NOUN'), (('Boorse', 'ADP'), ('Boorse', 'NOUN'))],
#  [(',', '.'), (('Horsham', 'ADP'), ('Horsham', 'NOUN'))],
#  [('David', 'NOUN'), (('Chiodo', 'ADP'), ('Chiodo', 'NOUN'))],
#  [(';', '.'), (('Camille', 'ADP'), ('Camille', 'NOUN'))],
#  [('Camille', 'NOUN'), (('Chafic', 'ADP'), ('Chafic', 'NOUN'))],
#  [('Chafic', 'NOUN'), (('Cotran', 'ADP'), ('Cotran', 'NOUN'))],
#  [('been', 'VERB'), (('aiming', 'ADP'), ('aiming', 'VERB'))],
#  [('the', 'DET'), (('elderly', 'ADP'), ('elderly', 'ADJ'))],
#  [('a', 'DET'), (('tall', 'ADP'), ('tall', 'ADJ'))],
#  [(',', '.'), (('energetic', 'ADP'), ('energetic', 'ADJ'))],
#  [('spent', 'VERB'), (('much', 'ADV'), ('much', 'ADJ'))],
#  [('That', 'DET'), (('sounds', 'NOUN'), ('sounds', 'VERB'))],
#  [('sounds', 'VERB'), (('neat', 'ADP'), ('neat', 'ADJ'))],
#  [('--', '.'), (('propagandizes', 'ADP'), ('propagandizes', 'VERB'))],
#  [('quite', 'ADV'), (('brilliantly', 'ADP'), ('brilliantly', 'ADV'))],
#  [('Henry', 'NOUN'), (('Holt', 'ADP'), ('Holt', 'NOUN'))],
#  [(',', '.'), (('326', 'ADP'), ('326', 'NUM'))],
#  [('$', '.'), (('19.95', 'ADP'), ('19.95', 'NUM'))],
#  [('highly', 'ADV'), (('detailed', 'ADJ'), ('detailed', 'VERB'))],
#  [('a', 'DET'), (('reassuring', 'ADP'), ('reassuring', 'ADJ'))],
#  [('this', 'DET'), (('plaintive', 'ADP'), ('plaintive', 'ADJ'))],
#  [(',', '.'), (('high-minded', 'ADP'), ('high-minded', 'ADJ'))],
#  [('of', 'ADP'), (('assurance', 'ADP'), ('assurance', 'NOUN'))],
#  [('*', 'X'), (('reading', 'NOUN'), ('reading', 'VERB'))],
#  [('about', 'ADP'), (('sticky', 'ADP'), ('sticky', 'ADJ'))],
#  [('sticky', 'ADJ'), (('fingers', 'ADP'), ('fingers', 'NOUN'))],
#  [('and', 'CONJ'), (('sweaty', 'ADP'), ('sweaty', 'ADJ'))],
#  [('pull', 'VERB'), (('rhythmically', 'ADP'), ('rhythmically', 'ADV'))],
#  [('bells', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('that', 'DET'), (('*T*-220', 'ADP'), ('*T*-220', 'X'))],
#  [('*T*-220', 'X'), (('first', 'ADJ'), ('first', 'ADV'))],
#  [('in', 'ADP'), (('1614', 'ADP'), ('1614', 'NUM'))],
#  [('get', 'VERB'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('.', '.'), (('FreudToy', 'ADP'), ('FreudToy', 'NOUN'))],
#  [('a', 'DET'), (('pillow', 'ADP'), ('pillow', 'NOUN'))],
#  [('pillow', 'NOUN'), (('bearing', 'NOUN'), ('bearing', 'VERB'))],
#  [('the', 'DET'), (('likeness', 'ADP'), ('likeness', 'NOUN'))],
#  [('of', 'ADP'), (('Sigmund', 'ADP'), ('Sigmund', 'NOUN'))],
#  [('Sigmund', 'NOUN'), (('Freud', 'ADP'), ('Freud', 'NOUN'))],
#  [('$', '.'), (('24.95', 'ADP'), ('24.95', 'NUM'))],
#  [('*U*', 'X'), (('tool', 'ADP'), ('tool', 'NOUN'))],
#  [('for', 'ADP'), (('do-it-yourself', 'ADP'), ('do-it-yourself', 'ADJ'))],
#  [('.', '.'), (('Packages', 'ADP'), ('Packages', 'NOUN'))],
#  [('*-1', 'X'), (('rewarding', 'ADP'), ('rewarding', 'VERB'))],
#  [('the', 'DET'), (('Colorliner', 'ADP'), ('Colorliner', 'NOUN'))],
#  [('Colorliner', 'NOUN'),
#   (('newspaper-printing', 'ADP'), ('newspaper-printing', 'NOUN'))],
#  [('telephone', 'NOUN'), (('call', 'VERB'), ('call', 'NOUN'))],
#  [('thing', 'NOUN'), (('happened', 'ADP'), ('happened', 'VERB'))],
#  [('in', 'ADP'), (('Islamabad', 'ADP'), ('Islamabad', 'NOUN'))],
#  [("'s", 'PRT'), (('237-seat', 'ADP'), ('237-seat', 'ADJ'))],
#  [('was', 'VERB'), (('rigged', 'ADP'), ('rigged', 'VERB'))],
#  [('The', 'DET'), (('Continental', 'ADP'), ('Continental', 'NOUN'))],
#  [('Continental', 'NOUN'), (('Baking', 'ADP'), ('Baking', 'NOUN'))],
#  [('on', 'ADP'), (('bread', 'ADP'), ('bread', 'NOUN'))],
#  [('this', 'DET'), (('commercial', 'ADJ'), ('commercial', 'NOUN'))],
#  [('Bob', 'NOUN'), (('Squier', 'ADP'), ('Squier', 'NOUN'))],
#  [('own', 'ADJ'), (('mean', 'VERB'), ('mean', 'ADJ'))],
#  [('and', 'CONJ'), (('dirty', 'ADP'), ('dirty', 'ADJ'))],
#  [('programs', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('seem', 'VERB'), (('tailor-made', 'ADP'), ('tailor-made', 'ADJ'))],
#  [('has', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('year', 'NOUN'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('will', 'VERB'), (('adopt', 'ADP'), ('adopt', 'VERB'))],
#  [('net', 'ADJ'), (('importer', 'ADP'), ('importer', 'NOUN'))],
#  [('The', 'DET'), (('7.40', 'ADP'), ('7.40', 'NUM'))],
#  [('yield', 'VERB'), (('7.45', 'ADP'), ('7.45', 'NUM'))],
#  [('and', 'CONJ'), (('7.40', 'ADP'), ('7.40', 'NUM'))],
#  [('yield', 'VERB'), (('7.50', 'ADP'), ('7.50', 'NUM'))],
#  [('.', '.'), (('ASLACTON', 'ADP'), ('ASLACTON', 'NOUN'))],
#  [('totaled', 'VERB'), (('11,390,000', 'ADP'), ('11,390,000', 'NUM'))],
#  [('is', 'VERB'), (('payable', 'ADP'), ('payable', 'ADJ'))],
#  [('payable', 'ADJ'), (('Jan.', 'ADP'), ('Jan.', 'NOUN'))],
#  [('*EXP*-1', 'X'), (("'s", 'PRT'), ("'s", 'VERB'))],
#  [('always', 'ADV'), (('walking', 'ADP'), ('walking', 'VERB'))],
#  [('to', 'PRT'), (('display', 'ADP'), ('display', 'VERB'))],
#  [('overhead', 'ADJ'), (('projector', 'ADP'), ('projector', 'NOUN'))],
#  [('and', 'CONJ'), (('underline', 'ADP'), ('underline', 'VERB'))],
#  [('$', '.'), (('234.4', 'ADP'), ('234.4', 'NUM'))],
#  [('rising', 'VERB'), (('5.4', 'ADP'), ('5.4', 'NUM'))],
#  [('``', '.'), (('Wa', '.'), ('Wa', 'NOUN'))],
#  [('is', 'VERB'), (('Japanese', 'ADJ'), ('Japanese', 'NOUN'))],
#  [('were', 'VERB'), (('carrying', 'ADP'), ('carrying', 'VERB'))],
#  [("'s", 'PRT'), (('sensitivity', 'ADP'), ('sensitivity', 'NOUN'))],
#  [('$', '.'), (('55-a-share', 'ADP'), ('55-a-share', 'ADJ'))],
#  [('*U*', 'X'), (('bid', 'VERB'), ('bid', 'NOUN'))],
#  [('bid', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [(',', '.'), (('steps', 'NOUN'), ('steps', 'VERB'))],
#  [('.', '.'), (('Fourteen', 'ADP'), ('Fourteen', 'NUM'))],
#  [('with', 'ADP'), (('jurisdiction', 'ADP'), ('jurisdiction', 'NOUN'))],
#  [('the', 'DET'), (('EEOC', 'ADP'), ('EEOC', 'NOUN'))],
#  [('his', 'PRON'), (('judgment', 'ADP'), ('judgment', 'NOUN'))],
#  [("''", '.'), (('Precious', 'ADP'), ('Precious', 'ADJ'))],
#  [('being', 'VERB'), (('influenced', 'ADP'), ('influenced', 'VERB'))],
#  [('*-1', 'X'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('William', 'NOUN'), (("O'Neill", 'ADP'), ("O'Neill", 'NOUN'))],
#  [('at', 'ADP'), (('Elders', 'ADP'), ('Elders', 'NOUN'))],
#  [('would', 'VERB'), (('junk', 'NOUN'), ('junk', 'VERB'))],
#  [('an', 'DET'), (('innovative', 'ADP'), ('innovative', 'ADJ'))],
#  [('innovative', 'ADJ'), (('market-based', 'ADP'), ('market-based', 'ADJ'))],
#  [('*', 'X'), (('trading', 'NOUN'), ('trading', 'VERB'))],
#  [('among', 'ADP'), (('polluters', 'ADP'), ('polluters', 'NOUN'))],
#  [('J.', 'NOUN'), (('McCabe', 'ADP'), ('McCabe', 'NOUN'))],
#  [('never', 'ADV'), (('materialized', 'ADP'), ('materialized', 'VERB'))],
#  [('a', 'DET'), (('stream', 'ADP'), ('stream', 'NOUN'))],
#  [('``', '.'), (('tire-kickers', 'ADP'), ('tire-kickers', 'NOUN'))],
#  [('and', 'CONJ'), (('lookee-loos', 'ADP'), ('lookee-loos', 'NOUN'))],
#  [('final', 'ADJ'), (('modification', 'ADP'), ('modification', 'NOUN'))],
#  [('made', 'VERB'), (('*-130', 'ADP'), ('*-130', 'X'))],
#  [('five-point', 'ADJ'), (('opening', 'NOUN'), ('opening', 'VERB'))],
#  [('biggest', 'ADJ'), (('issuers', 'ADP'), ('issuers', 'NOUN'))],
#  [('corporate', 'ADJ'), (('IOUs', 'ADP'), ('IOUs', 'NOUN'))],
#  [('a', 'DET'), (('public-relations', 'ADP'), ('public-relations', 'NOUN'))],
#  [('machine', 'NOUN'), (('that', 'ADP'), ('that', 'DET'))],
#  [('*T*-2', 'X'), (('sends', 'ADP'), ('sends', 'VERB'))],
#  [('you', 'PRON'), (('stuff', 'ADP'), ('stuff', 'NOUN'))],
#  [('Van', 'NOUN'), (('Alstyne', 'ADP'), ('Alstyne', 'NOUN'))],
#  [('Alstyne', 'NOUN'), (('notes', 'NOUN'), ('notes', 'VERB'))],
#  [('bad', 'ADJ'), (('apple', 'ADP'), ('apple', 'NOUN'))],
#  [('his', 'PRON'), (('apples', 'ADP'), ('apples', 'NOUN'))],
#  [('a', 'DET'), (('close', 'NOUN'), ('close', 'ADJ'))],
#  [('close', 'ADJ'), (('watch', 'VERB'), ('watch', 'NOUN'))],
#  [('take', 'VERB'), (('away', 'ADV'), ('away', 'PRT'))],
#  [('and', 'CONJ'), (('incest', 'ADP'), ('incest', 'NOUN'))],
#  [('*-3', 'X'), (('transforming', 'ADP'), ('transforming', 'VERB'))],
#  [('*', 'X'), (('PORTING', 'ADP'), ('PORTING', 'VERB'))],
#  [('PORTING', 'VERB'), (('POTABLES', 'ADP'), ('POTABLES', 'NOUN'))],
#  [('claims', 'VERB'), (('Scypher', 'ADP'), ('Scypher', 'NOUN'))],
#  [('the', 'DET'), (('Cup-Tote', 'ADP'), ('Cup-Tote', 'NOUN'))],
#  [('were', 'VERB'), (('overdone', 'ADP'), ('overdone', 'VERB'))],
#  [('a', 'DET'), (('reversal', 'ADP'), ('reversal', 'NOUN'))],
#  [('--', '.'), (('which', 'DET'), ('which', 'ADP'))],
#  [('*T*-1', 'X'), (('earlier', 'ADV'), ('earlier', 'ADJ'))],
#  [('--', '.'), (('agreed', 'VERB'), ('agreed', 'NOUN'))],
#  [('to', 'PRT'), (('supply', 'NOUN'), ('supply', 'VERB'))],
#  [('supply', 'VERB'), (('more', 'ADV'), ('more', 'ADJ'))],
#  [('the', 'DET'), (('Backer', 'ADP'), ('Backer', 'NOUN'))],
#  [('Backer', 'NOUN'), (('Spielvogel', 'ADP'), ('Spielvogel', 'NOUN'))],
#  [('Spielvogel', 'NOUN'), (('Bates', 'ADP'), ('Bates', 'NOUN'))],
#  [('the', 'DET'), (('colony', 'ADP'), ('colony', 'NOUN'))],
#  [('other', 'ADJ'), (('surveyed', 'ADP'), ('surveyed', 'VERB'))],
#  [('.', '.'), (('Short', 'ADP'), ('Short', 'ADJ'))],
#  [('a', 'DET'), (('total', 'ADJ'), ('total', 'NOUN'))],
#  [('several', 'ADJ'), (('middle-ground', 'ADP'), ('middle-ground', 'ADJ'))],
#  [('take', 'VERB'), (('away', 'ADV'), ('away', 'PRT'))],
#  [('currently', 'ADV'), (('enjoy', 'ADP'), ('enjoy', 'VERB'))],
#  [("'s", 'PRT'),
#   (('industrial-production', 'ADP'), ('industrial-production', 'ADJ'))],
#  [('resistance', 'NOUN'), (('standard', 'ADJ'), ('standard', 'NOUN'))],
#  [('.', '.'), (('Yet', 'CONJ'), ('Yet', 'ADV'))],
#  [('the', 'DET'), (('executive', 'NOUN'), ('executive', 'ADJ'))],
#  [('any', 'DET'), (('appropriation', 'ADP'), ('appropriation', 'NOUN'))],
#  [('the', 'DET'), (('filling', 'VERB'), ('filling', 'NOUN'))],
#  [('to', 'PRT'), (('double', 'ADJ'), ('double', 'VERB'))],
#  [('13', 'NUM'), (('page-one', 'NOUN'), ('page-one', 'ADJ'))],
#  [('of', 'ADP'), (('Western', 'ADJ'), ('Western', 'NOUN'))],
#  [('that', 'ADP'), (('Western', 'ADJ'), ('Western', 'NOUN'))],
#  [('turning', 'VERB'), (('down', 'ADV'), ('down', 'PRT'))],
#  [('down', 'PRT'), (('Alexander', 'ADP'), ('Alexander', 'NOUN'))],
#  [('Alexander', 'NOUN'), (('Graham', 'ADP'), ('Graham', 'NOUN'))],
#  [("'s", 'PRT'), (('offer', 'VERB'), ('offer', 'NOUN'))],
#  [('his', 'PRON'), (('invention', 'ADP'), ('invention', 'NOUN'))],
#  [('voice', 'NOUN'), (('communication', 'ADP'), ('communication', 'NOUN'))],
#  [('the', 'DET'), (('telegraph', 'VERB'), ('telegraph', 'NOUN'))],
#  [('--', '.'), (('if', 'ADP'), ('if', 'ADJ'))],
#  [('for', 'ADP'), (('pride', 'ADP'), ('pride', 'NOUN'))],
#  [('larger', 'ADJ'), (('captive', 'ADP'), ('captive', 'NOUN'))],
#  [('captive', 'NOUN'), (('audience', 'ADP'), ('audience', 'NOUN'))],
#  [('that', 'DET'), (('*T*-204', 'ADP'), ('*T*-204', 'X'))],
#  [('is', 'VERB'), (('less', 'ADJ'), ('less', 'ADV'))],
#  [('Old', 'NOUN'), (('Gringo', 'ADP'), ('Gringo', 'NOUN'))],
#  [('a', 'DET'), (('confused', 'VERB'), ('confused', 'ADJ'))],
#  [('confused', 'ADJ'), (('rendering', 'ADP'), ('rendering', 'NOUN'))],
#  [('Carlos', 'NOUN'), (('Fuentes', 'ADP'), ('Fuentes', 'NOUN'))],
#  [('the', 'DET'), (('Mexican', 'ADP'), ('Mexican', 'NOUN'))],
#  [('Mexican', 'NOUN'), (('Revolution', 'ADP'), ('Revolution', 'NOUN'))],
#  [('.', '.'), (('AN', 'ADP'), ('AN', 'DET'))],
#  [('AN', 'DET'), (('EXCHANGE', 'ADP'), ('EXCHANGE', 'NOUN'))],
#  [('promises', 'VERB'), (('change', 'VERB'), ('change', 'NOUN'))],
#  [('*-1', 'X'), (('trading', 'NOUN'), ('trading', 'VERB'))],
#  [('.', '.'), (('Academically', 'ADP'), ('Academically', 'ADV'))],
#  [('two', 'NUM'), (('disparate', 'ADP'), ('disparate', 'ADJ'))],
#  [('evenly', 'ADV'), (('split', 'VERB'), ('split', 'ADJ'))],
#  [('a', 'DET'), (('privileged', 'ADP'), ('privileged', 'ADJ'))],
#  [('white', 'ADJ'), (('elite', 'ADP'), ('elite', 'NOUN'))],
#  [('old', 'ADJ'), (('monied', 'ADP'), ('monied', 'ADJ'))],
#  [('monied', 'ADJ'), (('neighborhoods', 'ADP'), ('neighborhoods', 'NOUN'))],
#  [(',', '.'), (('inner', 'ADP'), ('inner', 'ADJ'))],
#  [('city', 'NOUN'), (('neighborhoods', 'ADP'), ('neighborhoods', 'NOUN'))],
#  [('*', 'X'), (('reinstating', 'ADP'), ('reinstating', 'VERB'))],
#  [('*', 'X'), (('Choose', 'ADP'), ('Choose', 'VERB'))],
#  [('them', 'PRON'), (('out', 'PRT'), ('out', 'ADP'))],
#  [('be', 'VERB'), (('deprived', 'ADP'), ('deprived', 'VERB'))],
#  [(',', '.'), (('families', 'ADP'), ('families', 'NOUN'))],
#  [('his', 'PRON'), (('name', 'VERB'), ('name', 'NOUN'))],
#  [('.', '.'), (('Billings', 'ADP'), ('Billings', 'NOUN'))],
#  [('which', 'DET'), (('*T*-155', 'ADP'), ('*T*-155', 'X'))],
#  [('been', 'VERB'), (('serviced', 'ADP'), ('serviced', 'VERB'))],
#  [("n't", 'ADV'), (('replicated', 'ADP'), ('replicated', 'VERB'))],
#  [('what', 'PRON'), (('*T*-252', 'ADP'), ('*T*-252', 'X'))],
#  [('*-1', 'X'), (('complaining', 'ADP'), ('complaining', 'VERB'))],
#  [('ended', 'VERB'), (('up', 'ADV'), ('up', 'PRT'))],
#  [('former', 'ADJ'), (('ratepayers', 'ADP'), ('ratepayers', 'NOUN'))],
#  [('cost', 'NOUN'), (('overruns', 'ADP'), ('overruns', 'NOUN'))],
#  [('reached', 'VERB'), (('*-120', 'ADP'), ('*-120', 'X'))],
#  [('stockbrokers', 'NOUN'), (('battle', 'NOUN'), ('battle', 'VERB'))],
#  [('few', 'ADJ'), (('floors', 'ADP'), ('floors', 'NOUN'))],
#  [('*-1', 'X'), (('sketching', 'ADP'), ('sketching', 'VERB'))],
#  [('sketching', 'VERB'), (('passers-by', 'ADP'), ('passers-by', 'NOUN'))],
#  [('it', 'PRON'), (('up', 'ADV'), ('up', 'PRT'))]]

# %% [markdown]
# ### Observations on incorrect tagging on test set

# %% [markdown]
# -- Unknown words (which are not preset in train set) are getting tagged by default to ADP (first tag).
#
# -- Numbers are not tagged correctly
#
# -- confused in Noun and verb tags, Nouns are getting tagged as verb and vise-versa

# %% [markdown]
# ### Solving the problem of unknown words

# %%
incorrect_tag_word = [[i for i, j in zip(tagged_seq, test_run_base) if i != j]]
incorrect_tag_word
# Out:
# [[('rule', 'NOUN'),
#   ("D'Amico", 'ADP'),
#   ('slow', 'VERB'),
#   ('computerize', 'ADP'),
#   ('target', 'NOUN'),
#   ('niches', 'ADP'),
#   ('*T*-199', 'ADP'),
#   ('rates', 'NOUN'),
#   ('study', 'VERB'),
#   ('waive', 'ADP'),
#   ('protective', 'ADP'),
#   ('golden', 'ADP'),
#   ('biscuit', 'ADP'),
#   ('Lazzaroni', 'ADP'),
#   ('overproduction', 'ADP'),
#   ('so', 'ADV'),
#   ('lieutenant', 'ADP'),
#   ('Fishman', 'ADP'),
#   ('Longwood', 'ADP'),
#   ('Floyd', 'ADP'),
#   ('Amin', 'ADP'),
#   ('Jalaalwalikraam', 'ADP'),
#   ('Glenham', 'ADP'),
#   ('Knapp', 'ADP'),
#   ('Deborah', 'ADP'),
#   ('Renee', 'ADP'),
#   ('Francis', 'ADP'),
#   ('Muscolina', 'ADP'),
#   ('Palisades', 'ADP'),
#   ('Najarian', 'ADP'),
#   ('Minn.', 'ADP'),
#   ('Norwick', 'ADP'),
#   ('Nesconset', 'ADP'),
#   ('views', 'VERB'),
#   ('IRAs', 'ADP'),
#   ('Output', 'ADP'),
#   ('gradually', 'ADP'),
#   ('reaches', 'ADP'),
#   ('Pakistan', 'ADP'),
#   ('Bhutto', 'ADP'),
#   ('defeated', 'ADP'),
#   ('no-confidence', 'ADP'),
#   ('42-year', 'ADP'),
#   ('that', 'ADP'),
#   ('down', 'ADV'),
#   ('11-month-old', 'ADP'),
#   ('Absorbed', 'ADP'),
#   ('doling', 'ADP'),
#   ('out', 'ADP'),
#   ('tidbits', 'ADP'),
#   ('gloss', 'ADP'),
#   ('root', 'ADP'),
#   ('A', 'DET'),
#   ('auspices', 'ADP'),
#   ('South', 'NOUN'),
#   ('African', 'NOUN'),
#   ('Items', 'ADP'),
#   ('numbered', 'ADP'),
#   ('about', 'ADP'),
#   ('newcomer', 'ADP'),
#   ('powder', 'ADP'),
#   ('that', 'ADP'),
#   ('*T*-119', 'ADP'),
#   ('expires', 'ADP'),
#   ('more', 'ADV'),
#   ('realestate', 'ADP'),
#   ('will', 'VERB'),
#   ('Topix', 'ADP'),
#   ('16.05', 'ADP'),
#   ('1.46', 'ADP'),
#   ('0.05', 'ADP'),
#   ('2691.19', 'ADP'),
#   ('imagine', 'ADP'),
#   ('racing', 'ADP'),
#   ('Chicago-style', 'ADP'),
#   ('arbitrager', 'ADP'),
#   ('that', 'ADP'),
#   ('*T*-227', 'ADP'),
#   ('stays', 'ADP'),
#   ('ABORTION', 'ADP'),
#   ('RULING', 'ADP'),
#   ('UPHELD', 'ADP'),
#   ('equipped', 'ADP'),
#   ('*-90', 'ADP'),
#   ('front-seat', 'ADP'),
#   ('headrests', 'ADP'),
#   ('*-91', 'ADP'),
#   ('16\\/32', 'ADP'),
#   ('Ind.', 'ADP'),
#   ('arched', 'ADP'),
#   ('G', 'ADP'),
#   ('Show', 'ADP'),
#   ('around', 'ADP'),
#   ('Huxtable', 'ADP'),
#   ('viewers', 'ADP'),
#   ('laughing', 'ADJ'),
#   ('interjects', 'ADP'),
#   ('interrogated', 'ADP'),
#   ('rapists', 'ADP'),
#   ('Conn.based', 'ADP'),
#   ('magnified', 'ADP'),
#   ('nonrecurring', 'ADP'),
#   ('8.2', 'ADP'),
#   ('asset-valuation', 'ADP'),
#   ('adjustments', 'ADP'),
#   ('that', 'DET'),
#   ('as', 'ADP'),
#   ('troublesome', 'ADP'),
#   ('Given', 'ADP'),
#   ('that', 'ADP'),
#   ('overpaying', 'ADP'),
#   ('about', 'ADP'),
#   ('crossed', 'ADP'),
#   ('gauging', 'ADP'),
#   ('early', 'ADJ'),
#   ('63.79', 'ADP'),
#   ('35500.64', 'ADP'),
#   ('Contra', 'ADP'),
#   ('command', 'VERB'),
#   ('Honduras', 'ADP'),
#   ('Sandinista', 'ADP'),
#   ('offensive', 'ADP'),
#   ('rebel', 'ADP'),
#   ('57.6', 'ADP'),
#   ('Yorkers', 'ADP'),
#   ('watch', 'NOUN'),
#   ('viewership', 'ADP'),
#   ('Impact', 'ADP'),
#   ('Columbus', 'ADP'),
#   ('that', 'ADP'),
#   ('diversified', 'ADJ'),
#   ('that', 'ADP'),
#   ('impressive', 'ADP'),
#   ('*T*-182', 'ADP'),
#   ('combat', 'ADP'),
#   ('import', 'NOUN'),
#   ('worth', 'ADJ'),
#   ('that', 'ADP'),
#   ('that', 'ADP'),
#   ('1,200', 'ADP'),
#   ('Mogavero', 'ADP'),
#   ('Piscataway', 'ADP'),
#   ('eight-count', 'ADP'),
#   ('indictment', 'ADP'),
#   ('Vice', 'ADP'),
#   ('Sherwin', 'ADP'),
#   ('manipulate', 'ADP'),
#   ('Carbide', 'ADP'),
#   ('planned', 'VERB'),
#   ('gilt', 'ADP'),
#   ('more', 'ADV'),
#   ('recovering', 'ADP'),
#   ('parishioners', 'ADP'),
#   ('Angels', 'ADP'),
#   ('chat', 'ADP'),
#   ('low-ball', 'ADP'),
#   ('purchasing', 'NOUN'),
#   ('confident', 'ADP'),
#   ('creditworthiness', 'ADP'),
#   ('rebuffed', 'ADP'),
#   ('study', 'NOUN'),
#   ('*T*-169', 'ADP'),
#   ('buy', 'NOUN'),
#   ('more', 'ADJ'),
#   ('knowledgeable', 'ADP'),
#   ('ago', 'ADP'),
#   ('implicit', 'ADP'),
#   ('Japanese', 'ADJ'),
#   ('Yet', 'CONJ'),
#   ('Wilmington', 'ADP'),
#   ('neoprene', 'ADP'),
#   ('rubber', 'ADP'),
#   ('supreme', 'ADP'),
#   ('Deng', 'ADP'),
#   ('Xiaoping', 'ADP'),
#   ('Frankly', 'ADP'),
#   ('speaking', 'ADP'),
#   ('*-146', 'ADP'),
#   ('deeply', 'ADP'),
#   ('counterrevolutionary', 'ADP'),
#   ('rebellion', 'ADP'),
#   ('*T*-243', 'ADP'),
#   ('long', 'ADJ'),
#   ('ago', 'ADP'),
#   ('forecast', 'NOUN'),
#   ('rise', 'VERB'),
#   ('5.4', 'ADP'),
#   ('disaffected', 'ADP'),
#   ('hard-drinking', 'ADP'),
#   ('nearly-30', 'ADP'),
#   ('sets', 'NOUN'),
#   ('snow', 'ADP'),
#   ('search', 'ADP'),
#   ('elusive', 'ADP'),
#   ('sheep', 'ADP'),
#   ('back', 'ADV'),
#   ('behest', 'ADP'),
#   ('sinister', 'ADP'),
#   ('erudite', 'ADP'),
#   ('mobster', 'ADP'),
#   ('C.J.B.', 'ADP'),
#   ('nearby', 'ADV'),
#   ('stairs', 'ADP'),
#   ('that', 'ADP'),
#   ('*-138', 'ADP'),
#   ('altar', 'ADP'),
#   ('right', 'NOUN'),
#   ('minute', 'ADJ'),
#   ('that', 'ADP'),
#   ('*T*-146', 'ADP'),
#   ('Stark', 'ADP'),
#   ('Robertson', 'ADP'),
#   ('Stephens', 'ADP'),
#   ('circuit-breaker', 'ADP'),
#   ('aggravated', 'ADP'),
#   ('directing', 'ADP'),
#   ('selling', 'NOUN'),
#   ('less', 'ADJ'),
#   ('index-arbitrage', 'ADJ'),
#   ('*-161', 'ADP'),
#   ('Barfield', 'ADP'),
#   ('Assurance', 'ADP'),
#   ('*T*-258', 'ADP'),
#   ('manages', 'ADP'),
#   ('23.72', 'ADP'),
#   ('broadly', 'ADP'),
#   ('construed', 'ADP'),
#   ('emasculate', 'ADP'),
#   ('swallow', 'ADP'),
#   ('forcing', 'ADJ'),
#   ('sites', 'ADP'),
#   ('labor-intensive', 'ADP'),
#   ('excess', 'NOUN'),
#   ('most', 'ADJ'),
#   ('earliest', 'ADP'),
#   ('pension-fund', 'ADP'),
#   ('steadily', 'ADP'),
#   ('dwindling', 'ADP'),
#   ('strong-willed', 'ADP'),
#   ('pressing', 'ADP'),
#   ('strong-willed', 'ADP'),
#   ('non-religious', 'ADP'),
#   ('drag-down', 'ADP'),
#   ('chaotic', 'ADP'),
#   ('trap', 'ADP'),
#   ('unwary', 'ADP'),
#   ('quantitative', 'ADP'),
#   ('interior', 'ADP'),
#   ('decorator', 'ADP'),
#   ('spook', 'ADP'),
#   ('sprawling', 'ADP'),
#   ('balkanized', 'ADP'),
#   ('mammoth', 'ADP'),
#   ('target', 'NOUN'),
#   ('Bellows', 'ADP'),
#   ('brightened', 'ADP'),
#   ('Image', 'ADP'),
#   ('*T*-170', 'ADP'),
#   ('*T*-171', 'ADP'),
#   ('*-100', 'ADP'),
#   ('Delaware', 'ADP'),
#   ('Dunkin', 'ADP'),
#   ('plans', 'VERB'),
#   ('deter', 'ADP'),
#   ('unworkable', 'ADP'),
#   ('executive', 'NOUN'),
#   ('unfunded', 'ADP'),
#   ('sign', 'NOUN'),
#   ('assert', 'ADP'),
#   ('restricting', 'ADP'),
#   ('context', 'ADP'),
#   ('characterized', 'ADP'),
#   ('excise', 'ADJ'),
#   ('that', 'ADP'),
#   ('objectionable', 'ADP'),
#   ('conflict', 'ADP'),
#   ('clear', 'ADJ'),
#   ('sell-off', 'ADP'),
#   ('Factories', 'ADP'),
#   ('booked', 'ADP'),
#   ('236.74', 'ADP'),
#   ('236.79', 'ADP'),
#   ('commercial', 'NOUN'),
#   ('distasteful', 'ADP'),
#   ('more', 'ADJ'),
#   ('newsworthy', 'ADP'),
#   ('Chinese', 'ADJ'),
#   ('undiplomatic', 'ADP'),
#   ('fashion', 'ADP'),
#   ('up', 'ADV'),
#   ('dismiss', 'ADP'),
#   ('sentimental', 'ADP'),
#   ('housing-assistance', 'ADP'),
#   ('sleeping', 'ADP'),
#   ('Reagan-Bush', 'ADP'),
#   ('report', 'VERB'),
#   ('journal', 'ADP'),
#   ('Nature', 'ADP'),
#   ('occurrences', 'ADP'),
#   ('help', 'VERB'),
#   ('revising', 'ADP'),
#   ('credit-rating', 'ADP'),
#   ('that', 'DET'),
#   ('forthcoming', 'ADP'),
#   ('10-year', 'ADJ'),
#   ('yen-denominated', 'ADP'),
#   ('about', 'ADP'),
#   ('redeeming', 'ADP'),
#   ('pretax', 'ADJ'),
#   ('like', 'ADP'),
#   ('14.75', 'ADP'),
#   ('most', 'ADJ'),
#   ('57.7', 'ADP'),
#   ('that', 'ADP'),
#   ('that', 'ADP'),
#   ('Sable', 'ADP'),
#   ('early', 'ADJ'),
#   ('experiencing', 'ADP'),
#   ('milked', 'ADP'),
#   ('*-117', 'ADP'),
#   ('as', 'ADP'),
#   ('principal', 'NOUN'),
#   ('fights', 'ADP'),
#   ('rechargeable', 'ADP'),
#   ('cadmium', 'ADP'),
#   ('carbon', 'ADP'),
#   ('zinc', 'ADP'),
#   ('movies', 'ADP'),
#   ('Peck', 'ADP'),
#   ('marvelously', 'ADP'),
#   ('loose', 'ADP'),
#   ('energetic', 'ADP'),
#   ('portrayal', 'ADP'),
#   ('Test-preparation', 'ADP'),
#   ('subindustry', 'ADP'),
#   ('grower', 'ADP'),
#   ('climb', 'ADP'),
#   ('566.54', 'ADP'),
#   ('forecast', 'NOUN'),
#   ('28.53', 'ADP'),
#   ('Derel', 'ADP'),
#   ('Adams', 'ADP'),
#   ('Killeen', 'ADP'),
#   ('Francis', 'ADP'),
#   ('Angier', 'ADP'),
#   ('Reddington', 'ADP'),
#   ('Shores', 'ADP'),
#   ('Arlington', 'ADP'),
#   ('Stirlen', 'ADP'),
#   ('Arlington', 'ADP'),
#   ('Bonnell', 'ADP'),
#   ('Boorse', 'ADP'),
#   ('Horsham', 'ADP'),
#   ('Chiodo', 'ADP'),
#   ('Camille', 'ADP'),
#   ('Chafic', 'ADP'),
#   ('Cotran', 'ADP'),
#   ('aiming', 'ADP'),
#   ('elderly', 'ADP'),
#   ('tall', 'ADP'),
#   ('energetic', 'ADP'),
#   ('much', 'ADV'),
#   ('sounds', 'NOUN'),
#   ('neat', 'ADP'),
#   ('propagandizes', 'ADP'),
#   ('brilliantly', 'ADP'),
#   ('Holt', 'ADP'),
#   ('326', 'ADP'),
#   ('19.95', 'ADP'),
#   ('detailed', 'ADJ'),
#   ('reassuring', 'ADP'),
#   ('plaintive', 'ADP'),
#   ('high-minded', 'ADP'),
#   ('assurance', 'ADP'),
#   ('reading', 'NOUN'),
#   ('sticky', 'ADP'),
#   ('fingers', 'ADP'),
#   ('sweaty', 'ADP'),
#   ('rhythmically', 'ADP'),
#   ('that', 'ADP'),
#   ('*T*-220', 'ADP'),
#   ('first', 'ADJ'),
#   ('1614', 'ADP'),
#   ('out', 'PRT'),
#   ('FreudToy', 'ADP'),
#   ('pillow', 'ADP'),
#   ('bearing', 'NOUN'),
#   ('likeness', 'ADP'),
#   ('Sigmund', 'ADP'),
#   ('Freud', 'ADP'),
#   ('24.95', 'ADP'),
#   ('tool', 'ADP'),
#   ('do-it-yourself', 'ADP'),
#   ('Packages', 'ADP'),
#   ('rewarding', 'ADP'),
#   ('Colorliner', 'ADP'),
#   ('newspaper-printing', 'ADP'),
#   ('call', 'VERB'),
#   ('happened', 'ADP'),
#   ('Islamabad', 'ADP'),
#   ('237-seat', 'ADP'),
#   ('rigged', 'ADP'),
#   ('Continental', 'ADP'),
#   ('Baking', 'ADP'),
#   ('bread', 'ADP'),
#   ('commercial', 'ADJ'),
#   ('Squier', 'ADP'),
#   ('mean', 'VERB'),
#   ('dirty', 'ADP'),
#   ('that', 'ADP'),
#   ('tailor-made', 'ADP'),
#   ('more', 'ADV'),
#   ('earlier', 'ADV'),
#   ('adopt', 'ADP'),
#   ('importer', 'ADP'),
#   ('7.40', 'ADP'),
#   ('7.45', 'ADP'),
#   ('7.40', 'ADP'),
#   ('7.50', 'ADP'),
#   ('ASLACTON', 'ADP'),
#   ('11,390,000', 'ADP'),
#   ('payable', 'ADP'),
#   ('Jan.', 'ADP'),
#   ("'s", 'PRT'),
#   ('walking', 'ADP'),
#   ('display', 'ADP'),
#   ('projector', 'ADP'),
#   ('underline', 'ADP'),
#   ('234.4', 'ADP'),
#   ('5.4', 'ADP'),
#   ('Wa', '.'),
#   ('Japanese', 'ADJ'),
#   ('carrying', 'ADP'),
#   ('sensitivity', 'ADP'),
#   ('55-a-share', 'ADP'),
#   ('bid', 'VERB'),
#   ('that', 'ADP'),
#   ('steps', 'NOUN'),
#   ('Fourteen', 'ADP'),
#   ('jurisdiction', 'ADP'),
#   ('EEOC', 'ADP'),
#   ('judgment', 'ADP'),
#   ('Precious', 'ADP'),
#   ('influenced', 'ADP'),
#   ('more', 'ADV'),
#   ("O'Neill", 'ADP'),
#   ('Elders', 'ADP'),
#   ('junk', 'NOUN'),
#   ('innovative', 'ADP'),
#   ('market-based', 'ADP'),
#   ('trading', 'NOUN'),
#   ('polluters', 'ADP'),
#   ('McCabe', 'ADP'),
#   ('materialized', 'ADP'),
#   ('stream', 'ADP'),
#   ('tire-kickers', 'ADP'),
#   ('lookee-loos', 'ADP'),
#   ('modification', 'ADP'),
#   ('*-130', 'ADP'),
#   ('opening', 'NOUN'),
#   ('issuers', 'ADP'),
#   ('IOUs', 'ADP'),
#   ('public-relations', 'ADP'),
#   ('that', 'ADP'),
#   ('sends', 'ADP'),
#   ('stuff', 'ADP'),
#   ('Alstyne', 'ADP'),
#   ('notes', 'NOUN'),
#   ('apple', 'ADP'),
#   ('apples', 'ADP'),
#   ('close', 'NOUN'),
#   ('watch', 'VERB'),
#   ('away', 'ADV'),
#   ('incest', 'ADP'),
#   ('transforming', 'ADP'),
#   ('PORTING', 'ADP'),
#   ('POTABLES', 'ADP'),
#   ('Scypher', 'ADP'),
#   ('Cup-Tote', 'ADP'),
#   ('overdone', 'ADP'),
#   ('reversal', 'ADP'),
#   ('which', 'DET'),
#   ('earlier', 'ADV'),
#   ('agreed', 'VERB'),
#   ('supply', 'NOUN'),
#   ('more', 'ADV'),
#   ('Backer', 'ADP'),
#   ('Spielvogel', 'ADP'),
#   ('Bates', 'ADP'),
#   ('colony', 'ADP'),
#   ('surveyed', 'ADP'),
#   ('Short', 'ADP'),
#   ('total', 'ADJ'),
#   ('middle-ground', 'ADP'),
#   ('away', 'ADV'),
#   ('enjoy', 'ADP'),
#   ('industrial-production', 'ADP'),
#   ('standard', 'ADJ'),
#   ('Yet', 'CONJ'),
#   ('executive', 'NOUN'),
#   ('appropriation', 'ADP'),
#   ('filling', 'VERB'),
#   ('double', 'ADJ'),
#   ('page-one', 'NOUN'),
#   ('Western', 'ADJ'),
#   ('Western', 'ADJ'),
#   ('down', 'ADV'),
#   ('Alexander', 'ADP'),
#   ('Graham', 'ADP'),
#   ('offer', 'VERB'),
#   ('invention', 'ADP'),
#   ('communication', 'ADP'),
#   ('telegraph', 'VERB'),
#   ('if', 'ADP'),
#   ('pride', 'ADP'),
#   ('captive', 'ADP'),
#   ('audience', 'ADP'),
#   ('*T*-204', 'ADP'),
#   ('less', 'ADJ'),
#   ('Gringo', 'ADP'),
#   ('confused', 'VERB'),
#   ('rendering', 'ADP'),
#   ('Fuentes', 'ADP'),
#   ('Mexican', 'ADP'),
#   ('Revolution', 'ADP'),
#   ('AN', 'ADP'),
#   ('EXCHANGE', 'ADP'),
#   ('change', 'VERB'),
#   ('trading', 'NOUN'),
#   ('Academically', 'ADP'),
#   ('disparate', 'ADP'),
#   ('split', 'VERB'),
#   ('privileged', 'ADP'),
#   ('elite', 'ADP'),
#   ('monied', 'ADP'),
#   ('neighborhoods', 'ADP'),
#   ('inner', 'ADP'),
#   ('neighborhoods', 'ADP'),
#   ('reinstating', 'ADP'),
#   ('Choose', 'ADP'),
#   ('out', 'PRT'),
#   ('deprived', 'ADP'),
#   ('families', 'ADP'),
#   ('name', 'VERB'),
#   ('Billings', 'ADP'),
#   ('*T*-155', 'ADP'),
#   ('serviced', 'ADP'),
#   ('replicated', 'ADP'),
#   ('*T*-252', 'ADP'),
#   ('complaining', 'ADP'),
#   ('up', 'ADV'),
#   ('ratepayers', 'ADP'),
#   ('overruns', 'ADP'),
#   ('*-120', 'ADP'),
#   ('battle', 'NOUN'),
#   ('floors', 'ADP'),
#   ('sketching', 'ADP'),
#   ('passers-by', 'ADP'),
#   ('up', 'ADV')]]

# %% [markdown]
# # Modification Method -1

# %% [markdown]
# ### Modifying viterbi to check unknown words and apply only transition probability for them (as in Vanilla Viterbi they are getting tagged by default as ADP)

# %%
# Viterbi Heuristic modified
def Viterbi_modified_1(words, train_bag = train_tagged_words):
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    tokens = list(set([pair[0] for pair in train_bag]))
    unknown_word = [word for word in words if word not in tokens]
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            if word in unknown_word:
                state_probability = transition_p
            else:
                state_probability = emission_p * transition_p
            
            p.append(state_probability)
            
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = T[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# ### Evaluating accuracy for method 1 on test set

# %%
start = time.time()
tagged_seq_1 = Viterbi_modified_1(test_tagged_words)
end = time.time()
print('Time required for execution:',end - start)
# Out:
# Time required for execution: 1127.5584042072296

# %%
check_1 = [i for i, j in zip(tagged_seq_1, test_run_base) if i == j]
print(len(check_1))
print(len(test_run_base))
print(len(tagged_seq_1))
# Out:
# 4756
# 5121
# 5121

# %%
accuracy_1 = len(check_1)/len(tagged_seq_1)
accuracy_1
# Out:
# 0.9287248584260887

# %% [markdown]
# ### Accuracy  is enhanced to  93 - 94%

# %% [markdown]
# ### Validation set performance with method 1

# %%
validation_tokens
# Out:
# ['Android',
#  'is',
#  'a',
#  'mobile',
#  'operating',
#  'system',
#  'developed',
#  'by',
#  'Google',
#  '.',
#  'Android',
#  'has',
#  'been',
#  'the',
#  'best-selling',
#  'OS',
#  'worldwide',
#  'on',
#  'smartphones',
#  'since',
#  '2011',
#  'and',
#  'on',
#  'tablets',
#  'since',
#  '2013',
#  '.',
#  'Google',
#  'and',
#  'Twitter',
#  'made',
#  'a',
#  'deal',
#  'in',
#  '2015',
#  'that',
#  'gave',
#  'Google',
#  'access',
#  'to',
#  'Twitter',
#  "'s",
#  'firehose',
#  '.',
#  'Twitter',
#  'is',
#  'an',
#  'online',
#  'news',
#  'and',
#  'social',
#  'networking',
#  'service',
#  'on',
#  'which',
#  'users',
#  'post',
#  'and',
#  'interact',
#  'with',
#  'messages',
#  'known',
#  'as',
#  'tweets',
#  '.',
#  'Before',
#  'entering',
#  'politics',
#  ',',
#  'Donald',
#  'Trump',
#  'was',
#  'a',
#  'domineering',
#  'businessman',
#  'and',
#  'a',
#  'television',
#  'personality',
#  '.',
#  'The',
#  '2018',
#  'FIFA',
#  'World',
#  'Cup',
#  'is',
#  'the',
#  '21st',
#  'FIFA',
#  'World',
#  'Cup',
#  ',',
#  'an',
#  'international',
#  'football',
#  'tournament',
#  'contested',
#  'once',
#  'every',
#  'four',
#  'years',
#  '.',
#  'This',
#  'is',
#  'the',
#  'first',
#  'World',
#  'Cup',
#  'to',
#  'be',
#  'held',
#  'in',
#  'Eastern',
#  'Europe',
#  'and',
#  'the',
#  '11th',
#  'time',
#  'that',
#  'it',
#  'has',
#  'been',
#  'held',
#  'in',
#  'Europe',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'cheapest',
#  'round',
#  'trips',
#  'from',
#  'Dallas',
#  'to',
#  'Atlanta',
#  'I',
#  'would',
#  'like',
#  'to',
#  'see',
#  'flights',
#  'from',
#  'Denver',
#  'to',
#  'Philadelphia',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'price',
#  'of',
#  'the',
#  'flights',
#  'leaving',
#  'Atlanta',
#  'at',
#  'about',
#  '3',
#  'in',
#  'the',
#  'afternoon',
#  'and',
#  'arriving',
#  'in',
#  'San',
#  'Francisco',
#  '.',
#  'NASA',
#  'invited',
#  'social',
#  'media',
#  'users',
#  'to',
#  'experience',
#  'the',
#  'launch',
#  'of',
#  'ICESAT-2',
#  'Satellite',
#  '.']

# %%
start = time.time()
tagged_seq_validation_1 = Viterbi_modified_1(validation_tokens)
end = time.time()
print('Time required for execution:',end - start)
# Out:
# Time required for execution: 45.58622884750366

# %%
tagged_seq_validation_1
# Out:
# [('Android', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google', 'DET'),
#  ('.', '.'),
#  ('Android', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('on', 'ADP'),
#  ('smartphones', 'DET'),
#  ('since', 'ADP'),
#  ('2011', 'DET'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013', 'DET'),
#  ('.', '.'),
#  ('Google', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Twitter', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'DET'),
#  ('that', 'ADP'),
#  ('gave', 'VERB'),
#  ('Google', 'X'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', 'VERB'),
#  ("'s", 'PRT'),
#  ('firehose', 'VERB'),
#  ('.', '.'),
#  ('Twitter', 'NOUN'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'NOUN'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'NOUN'),
#  ('with', 'ADP'),
#  ('messages', 'DET'),
#  ('known', 'VERB'),
#  ('as', 'ADP'),
#  ('tweets', 'DET'),
#  ('.', '.'),
#  ('Before', 'ADP'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('Donald', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'NOUN'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('2018', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('contested', 'NOUN'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years', 'NOUN'),
#  ('.', '.'),
#  ('This', 'DET'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Eastern', 'NOUN'),
#  ('Europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'ADJ'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Europe', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('from', 'ADP'),
#  ('Dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('Atlanta', 'NOUN'),
#  ('I', 'PRON'),
#  ('would', 'VERB'),
#  ('like', 'ADP'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('Denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('Philadelphia', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('Atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADP'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'NOUN'),
#  ('in', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('.', '.'),
#  ('NASA', 'NOUN'),
#  ('invited', 'NOUN'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'NOUN'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('ICESAT-2', 'DET'),
#  ('Satellite', 'NOUN'),
#  ('.', '.')]

# %% [markdown]
# #### Checking differently tagged words in validation set from vanilla viterbi and modified viterbi with method -1

# %%
diff = [[i,j] for i,j in zip(tagged_seq_validation_1,tagged_seq_validation) if i != j]
diff
# Out:
# [[('Android', 'NOUN'), ('Android', 'ADP')],
#  [('Google', 'DET'), ('Google', 'ADP')],
#  [('Android', 'NOUN'), ('Android', 'ADP')],
#  [('OS', 'NOUN'), ('OS', 'ADP')],
#  [('worldwide', 'NOUN'), ('worldwide', 'ADP')],
#  [('smartphones', 'DET'), ('smartphones', 'ADP')],
#  [('2011', 'DET'), ('2011', 'ADP')],
#  [('tablets', 'DET'), ('tablets', 'ADP')],
#  [('2013', 'DET'), ('2013', 'ADP')],
#  [('Google', 'NOUN'), ('Google', 'ADP')],
#  [('Twitter', 'NOUN'), ('Twitter', 'ADP')],
#  [('2015', 'DET'), ('2015', 'ADP')],
#  [('that', 'ADP'), ('that', 'DET')],
#  [('Google', 'X'), ('Google', 'ADP')],
#  [('Twitter', 'VERB'), ('Twitter', 'ADP')],
#  [('firehose', 'VERB'), ('firehose', 'ADP')],
#  [('Twitter', 'NOUN'), ('Twitter', 'ADP')],
#  [('online', 'NOUN'), ('online', 'ADP')],
#  [('networking', 'NOUN'), ('networking', 'ADP')],
#  [('interact', 'NOUN'), ('interact', 'ADP')],
#  [('messages', 'DET'), ('messages', 'ADP')],
#  [('known', 'VERB'), ('known', 'ADJ')],
#  [('tweets', 'DET'), ('tweets', 'ADP')],
#  [('domineering', 'NOUN'), ('domineering', 'ADP')],
#  [('personality', 'NOUN'), ('personality', 'ADP')],
#  [('2018', 'NOUN'), ('2018', 'ADP')],
#  [('FIFA', 'NOUN'), ('FIFA', 'ADP')],
#  [('Cup', 'NOUN'), ('Cup', 'ADP')],
#  [('21st', 'NOUN'), ('21st', 'ADP')],
#  [('FIFA', 'NOUN'), ('FIFA', 'ADP')],
#  [('Cup', 'NOUN'), ('Cup', 'ADP')],
#  [('tournament', 'NOUN'), ('tournament', 'ADP')],
#  [('contested', 'NOUN'), ('contested', 'ADP')],
#  [('Cup', 'NOUN'), ('Cup', 'ADP')],
#  [('trips', 'NOUN'), ('trips', 'ADP')],
#  [('arriving', 'NOUN'), ('arriving', 'ADP')],
#  [('NASA', 'NOUN'), ('NASA', 'ADP')],
#  [('invited', 'NOUN'), ('invited', 'ADP')],
#  [('ICESAT-2', 'DET'), ('ICESAT-2', 'ADP')],
#  [('Satellite', 'NOUN'), ('Satellite', 'ADP')]]

# %% [markdown]
# ### Comparing the tagging accuracies of the modifications with Method -1 with the vanilla Viterbi algorithm

# %% [markdown]
# **Vanilla Viterbi gave 91% accuracy and with modification of method 1 (for unknown words consider only transition probabilities) accuracy obtained is 94%

# %% [markdown]
# ### Cases which were incorrectly tagged by original POS tagger and got corrected modifications with Method -1

# %% [markdown]
# 1. Android is getting tagged as NOUN after modification which was coming as ADP by default

# %% [markdown]
# 2. NASA is getting correctly tagged as Noun

# %% [markdown]
# 3. FIFA is getting correctly tagged as Noun

# %% [markdown]
# 4. Google, Twitter is partially getting tagged Noun so still needs more rectification in method-1 but better from vanilla viterbi

# %% [markdown]
# # Modification Method -2

# %% [markdown]
# ### Using Unigram tagger and regex tagger to check performance of test set individually before integrating with Viterbi

# %% [markdown]
# -- Checking on incorrect tagged word we got from Vanilla Viterbi

# %%
incorrect_word= [tup[0] for tup in incorrect_tag_word[0]]
incorrect_word
# Out:
# ['rule',
#  "D'Amico",
#  'slow',
#  'computerize',
#  'target',
#  'niches',
#  '*T*-199',
#  'rates',
#  'study',
#  'waive',
#  'protective',
#  'golden',
#  'biscuit',
#  'Lazzaroni',
#  'overproduction',
#  'so',
#  'lieutenant',
#  'Fishman',
#  'Longwood',
#  'Floyd',
#  'Amin',
#  'Jalaalwalikraam',
#  'Glenham',
#  'Knapp',
#  'Deborah',
#  'Renee',
#  'Francis',
#  'Muscolina',
#  'Palisades',
#  'Najarian',
#  'Minn.',
#  'Norwick',
#  'Nesconset',
#  'views',
#  'IRAs',
#  'Output',
#  'gradually',
#  'reaches',
#  'Pakistan',
#  'Bhutto',
#  'defeated',
#  'no-confidence',
#  '42-year',
#  'that',
#  'down',
#  '11-month-old',
#  'Absorbed',
#  'doling',
#  'out',
#  'tidbits',
#  'gloss',
#  'root',
#  'A',
#  'auspices',
#  'South',
#  'African',
#  'Items',
#  'numbered',
#  'about',
#  'newcomer',
#  'powder',
#  'that',
#  '*T*-119',
#  'expires',
#  'more',
#  'realestate',
#  'will',
#  'Topix',
#  '16.05',
#  '1.46',
#  '0.05',
#  '2691.19',
#  'imagine',
#  'racing',
#  'Chicago-style',
#  'arbitrager',
#  'that',
#  '*T*-227',
#  'stays',
#  'ABORTION',
#  'RULING',
#  'UPHELD',
#  'equipped',
#  '*-90',
#  'front-seat',
#  'headrests',
#  '*-91',
#  '16\\/32',
#  'Ind.',
#  'arched',
#  'G',
#  'Show',
#  'around',
#  'Huxtable',
#  'viewers',
#  'laughing',
#  'interjects',
#  'interrogated',
#  'rapists',
#  'Conn.based',
#  'magnified',
#  'nonrecurring',
#  '8.2',
#  'asset-valuation',
#  'adjustments',
#  'that',
#  'as',
#  'troublesome',
#  'Given',
#  'that',
#  'overpaying',
#  'about',
#  'crossed',
#  'gauging',
#  'early',
#  '63.79',
#  '35500.64',
#  'Contra',
#  'command',
#  'Honduras',
#  'Sandinista',
#  'offensive',
#  'rebel',
#  '57.6',
#  'Yorkers',
#  'watch',
#  'viewership',
#  'Impact',
#  'Columbus',
#  'that',
#  'diversified',
#  'that',
#  'impressive',
#  '*T*-182',
#  'combat',
#  'import',
#  'worth',
#  'that',
#  'that',
#  '1,200',
#  'Mogavero',
#  'Piscataway',
#  'eight-count',
#  'indictment',
#  'Vice',
#  'Sherwin',
#  'manipulate',
#  'Carbide',
#  'planned',
#  'gilt',
#  'more',
#  'recovering',
#  'parishioners',
#  'Angels',
#  'chat',
#  'low-ball',
#  'purchasing',
#  'confident',
#  'creditworthiness',
#  'rebuffed',
#  'study',
#  '*T*-169',
#  'buy',
#  'more',
#  'knowledgeable',
#  'ago',
#  'implicit',
#  'Japanese',
#  'Yet',
#  'Wilmington',
#  'neoprene',
#  'rubber',
#  'supreme',
#  'Deng',
#  'Xiaoping',
#  'Frankly',
#  'speaking',
#  '*-146',
#  'deeply',
#  'counterrevolutionary',
#  'rebellion',
#  '*T*-243',
#  'long',
#  'ago',
#  'forecast',
#  'rise',
#  '5.4',
#  'disaffected',
#  'hard-drinking',
#  'nearly-30',
#  'sets',
#  'snow',
#  'search',
#  'elusive',
#  'sheep',
#  'back',
#  'behest',
#  'sinister',
#  'erudite',
#  'mobster',
#  'C.J.B.',
#  'nearby',
#  'stairs',
#  'that',
#  '*-138',
#  'altar',
#  'right',
#  'minute',
#  'that',
#  '*T*-146',
#  'Stark',
#  'Robertson',
#  'Stephens',
#  'circuit-breaker',
#  'aggravated',
#  'directing',
#  'selling',
#  'less',
#  'index-arbitrage',
#  '*-161',
#  'Barfield',
#  'Assurance',
#  '*T*-258',
#  'manages',
#  '23.72',
#  'broadly',
#  'construed',
#  'emasculate',
#  'swallow',
#  'forcing',
#  'sites',
#  'labor-intensive',
#  'excess',
#  'most',
#  'earliest',
#  'pension-fund',
#  'steadily',
#  'dwindling',
#  'strong-willed',
#  'pressing',
#  'strong-willed',
#  'non-religious',
#  'drag-down',
#  'chaotic',
#  'trap',
#  'unwary',
#  'quantitative',
#  'interior',
#  'decorator',
#  'spook',
#  'sprawling',
#  'balkanized',
#  'mammoth',
#  'target',
#  'Bellows',
#  'brightened',
#  'Image',
#  '*T*-170',
#  '*T*-171',
#  '*-100',
#  'Delaware',
#  'Dunkin',
#  'plans',
#  'deter',
#  'unworkable',
#  'executive',
#  'unfunded',
#  'sign',
#  'assert',
#  'restricting',
#  'context',
#  'characterized',
#  'excise',
#  'that',
#  'objectionable',
#  'conflict',
#  'clear',
#  'sell-off',
#  'Factories',
#  'booked',
#  '236.74',
#  '236.79',
#  'commercial',
#  'distasteful',
#  'more',
#  'newsworthy',
#  'Chinese',
#  'undiplomatic',
#  'fashion',
#  'up',
#  'dismiss',
#  'sentimental',
#  'housing-assistance',
#  'sleeping',
#  'Reagan-Bush',
#  'report',
#  'journal',
#  'Nature',
#  'occurrences',
#  'help',
#  'revising',
#  'credit-rating',
#  'that',
#  'forthcoming',
#  '10-year',
#  'yen-denominated',
#  'about',
#  'redeeming',
#  'pretax',
#  'like',
#  '14.75',
#  'most',
#  '57.7',
#  'that',
#  'that',
#  'Sable',
#  'early',
#  'experiencing',
#  'milked',
#  '*-117',
#  'as',
#  'principal',
#  'fights',
#  'rechargeable',
#  'cadmium',
#  'carbon',
#  'zinc',
#  'movies',
#  'Peck',
#  'marvelously',
#  'loose',
#  'energetic',
#  'portrayal',
#  'Test-preparation',
#  'subindustry',
#  'grower',
#  'climb',
#  '566.54',
#  'forecast',
#  '28.53',
#  'Derel',
#  'Adams',
#  'Killeen',
#  'Francis',
#  'Angier',
#  'Reddington',
#  'Shores',
#  'Arlington',
#  'Stirlen',
#  'Arlington',
#  'Bonnell',
#  'Boorse',
#  'Horsham',
#  'Chiodo',
#  'Camille',
#  'Chafic',
#  'Cotran',
#  'aiming',
#  'elderly',
#  'tall',
#  'energetic',
#  'much',
#  'sounds',
#  'neat',
#  'propagandizes',
#  'brilliantly',
#  'Holt',
#  '326',
#  '19.95',
#  'detailed',
#  'reassuring',
#  'plaintive',
#  'high-minded',
#  'assurance',
#  'reading',
#  'sticky',
#  'fingers',
#  'sweaty',
#  'rhythmically',
#  'that',
#  '*T*-220',
#  'first',
#  '1614',
#  'out',
#  'FreudToy',
#  'pillow',
#  'bearing',
#  'likeness',
#  'Sigmund',
#  'Freud',
#  '24.95',
#  'tool',
#  'do-it-yourself',
#  'Packages',
#  'rewarding',
#  'Colorliner',
#  'newspaper-printing',
#  'call',
#  'happened',
#  'Islamabad',
#  '237-seat',
#  'rigged',
#  'Continental',
#  'Baking',
#  'bread',
#  'commercial',
#  'Squier',
#  'mean',
#  'dirty',
#  'that',
#  'tailor-made',
#  'more',
#  'earlier',
#  'adopt',
#  'importer',
#  '7.40',
#  '7.45',
#  '7.40',
#  '7.50',
#  'ASLACTON',
#  '11,390,000',
#  'payable',
#  'Jan.',
#  "'s",
#  'walking',
#  'display',
#  'projector',
#  'underline',
#  '234.4',
#  '5.4',
#  'Wa',
#  'Japanese',
#  'carrying',
#  'sensitivity',
#  '55-a-share',
#  'bid',
#  'that',
#  'steps',
#  'Fourteen',
#  'jurisdiction',
#  'EEOC',
#  'judgment',
#  'Precious',
#  'influenced',
#  'more',
#  "O'Neill",
#  'Elders',
#  'junk',
#  'innovative',
#  'market-based',
#  'trading',
#  'polluters',
#  'McCabe',
#  'materialized',
#  'stream',
#  'tire-kickers',
#  'lookee-loos',
#  'modification',
#  '*-130',
#  'opening',
#  'issuers',
#  'IOUs',
#  'public-relations',
#  'that',
#  'sends',
#  'stuff',
#  'Alstyne',
#  'notes',
#  'apple',
#  'apples',
#  'close',
#  'watch',
#  'away',
#  'incest',
#  'transforming',
#  'PORTING',
#  'POTABLES',
#  'Scypher',
#  'Cup-Tote',
#  'overdone',
#  'reversal',
#  'which',
#  'earlier',
#  'agreed',
#  'supply',
#  'more',
#  'Backer',
#  'Spielvogel',
#  'Bates',
#  'colony',
#  'surveyed',
#  'Short',
#  'total',
#  'middle-ground',
#  'away',
#  'enjoy',
#  'industrial-production',
#  'standard',
#  'Yet',
#  'executive',
#  'appropriation',
#  'filling',
#  'double',
#  'page-one',
#  'Western',
#  'Western',
#  'down',
#  'Alexander',
#  'Graham',
#  'offer',
#  'invention',
#  'communication',
#  'telegraph',
#  'if',
#  'pride',
#  'captive',
#  'audience',
#  '*T*-204',
#  'less',
#  'Gringo',
#  'confused',
#  'rendering',
#  'Fuentes',
#  'Mexican',
#  'Revolution',
#  'AN',
#  'EXCHANGE',
#  'change',
#  'trading',
#  'Academically',
#  'disparate',
#  'split',
#  'privileged',
#  'elite',
#  'monied',
#  'neighborhoods',
#  'inner',
#  'neighborhoods',
#  'reinstating',
#  'Choose',
#  'out',
#  'deprived',
#  'families',
#  'name',
#  'Billings',
#  '*T*-155',
#  'serviced',
#  'replicated',
#  '*T*-252',
#  'complaining',
#  'up',
#  'ratepayers',
#  'overruns',
#  '*-120',
#  'battle',
#  'floors',
#  'sketching',
#  'passers-by',
#  'up']

# %%
incorrect_tag_word
# Out:
# [[('rule', 'NOUN'),
#   ("D'Amico", 'ADP'),
#   ('slow', 'VERB'),
#   ('computerize', 'ADP'),
#   ('target', 'NOUN'),
#   ('niches', 'ADP'),
#   ('*T*-199', 'ADP'),
#   ('rates', 'NOUN'),
#   ('study', 'VERB'),
#   ('waive', 'ADP'),
#   ('protective', 'ADP'),
#   ('golden', 'ADP'),
#   ('biscuit', 'ADP'),
#   ('Lazzaroni', 'ADP'),
#   ('overproduction', 'ADP'),
#   ('so', 'ADV'),
#   ('lieutenant', 'ADP'),
#   ('Fishman', 'ADP'),
#   ('Longwood', 'ADP'),
#   ('Floyd', 'ADP'),
#   ('Amin', 'ADP'),
#   ('Jalaalwalikraam', 'ADP'),
#   ('Glenham', 'ADP'),
#   ('Knapp', 'ADP'),
#   ('Deborah', 'ADP'),
#   ('Renee', 'ADP'),
#   ('Francis', 'ADP'),
#   ('Muscolina', 'ADP'),
#   ('Palisades', 'ADP'),
#   ('Najarian', 'ADP'),
#   ('Minn.', 'ADP'),
#   ('Norwick', 'ADP'),
#   ('Nesconset', 'ADP'),
#   ('views', 'VERB'),
#   ('IRAs', 'ADP'),
#   ('Output', 'ADP'),
#   ('gradually', 'ADP'),
#   ('reaches', 'ADP'),
#   ('Pakistan', 'ADP'),
#   ('Bhutto', 'ADP'),
#   ('defeated', 'ADP'),
#   ('no-confidence', 'ADP'),
#   ('42-year', 'ADP'),
#   ('that', 'ADP'),
#   ('down', 'ADV'),
#   ('11-month-old', 'ADP'),
#   ('Absorbed', 'ADP'),
#   ('doling', 'ADP'),
#   ('out', 'ADP'),
#   ('tidbits', 'ADP'),
#   ('gloss', 'ADP'),
#   ('root', 'ADP'),
#   ('A', 'DET'),
#   ('auspices', 'ADP'),
#   ('South', 'NOUN'),
#   ('African', 'NOUN'),
#   ('Items', 'ADP'),
#   ('numbered', 'ADP'),
#   ('about', 'ADP'),
#   ('newcomer', 'ADP'),
#   ('powder', 'ADP'),
#   ('that', 'ADP'),
#   ('*T*-119', 'ADP'),
#   ('expires', 'ADP'),
#   ('more', 'ADV'),
#   ('realestate', 'ADP'),
#   ('will', 'VERB'),
#   ('Topix', 'ADP'),
#   ('16.05', 'ADP'),
#   ('1.46', 'ADP'),
#   ('0.05', 'ADP'),
#   ('2691.19', 'ADP'),
#   ('imagine', 'ADP'),
#   ('racing', 'ADP'),
#   ('Chicago-style', 'ADP'),
#   ('arbitrager', 'ADP'),
#   ('that', 'ADP'),
#   ('*T*-227', 'ADP'),
#   ('stays', 'ADP'),
#   ('ABORTION', 'ADP'),
#   ('RULING', 'ADP'),
#   ('UPHELD', 'ADP'),
#   ('equipped', 'ADP'),
#   ('*-90', 'ADP'),
#   ('front-seat', 'ADP'),
#   ('headrests', 'ADP'),
#   ('*-91', 'ADP'),
#   ('16\\/32', 'ADP'),
#   ('Ind.', 'ADP'),
#   ('arched', 'ADP'),
#   ('G', 'ADP'),
#   ('Show', 'ADP'),
#   ('around', 'ADP'),
#   ('Huxtable', 'ADP'),
#   ('viewers', 'ADP'),
#   ('laughing', 'ADJ'),
#   ('interjects', 'ADP'),
#   ('interrogated', 'ADP'),
#   ('rapists', 'ADP'),
#   ('Conn.based', 'ADP'),
#   ('magnified', 'ADP'),
#   ('nonrecurring', 'ADP'),
#   ('8.2', 'ADP'),
#   ('asset-valuation', 'ADP'),
#   ('adjustments', 'ADP'),
#   ('that', 'DET'),
#   ('as', 'ADP'),
#   ('troublesome', 'ADP'),
#   ('Given', 'ADP'),
#   ('that', 'ADP'),
#   ('overpaying', 'ADP'),
#   ('about', 'ADP'),
#   ('crossed', 'ADP'),
#   ('gauging', 'ADP'),
#   ('early', 'ADJ'),
#   ('63.79', 'ADP'),
#   ('35500.64', 'ADP'),
#   ('Contra', 'ADP'),
#   ('command', 'VERB'),
#   ('Honduras', 'ADP'),
#   ('Sandinista', 'ADP'),
#   ('offensive', 'ADP'),
#   ('rebel', 'ADP'),
#   ('57.6', 'ADP'),
#   ('Yorkers', 'ADP'),
#   ('watch', 'NOUN'),
#   ('viewership', 'ADP'),
#   ('Impact', 'ADP'),
#   ('Columbus', 'ADP'),
#   ('that', 'ADP'),
#   ('diversified', 'ADJ'),
#   ('that', 'ADP'),
#   ('impressive', 'ADP'),
#   ('*T*-182', 'ADP'),
#   ('combat', 'ADP'),
#   ('import', 'NOUN'),
#   ('worth', 'ADJ'),
#   ('that', 'ADP'),
#   ('that', 'ADP'),
#   ('1,200', 'ADP'),
#   ('Mogavero', 'ADP'),
#   ('Piscataway', 'ADP'),
#   ('eight-count', 'ADP'),
#   ('indictment', 'ADP'),
#   ('Vice', 'ADP'),
#   ('Sherwin', 'ADP'),
#   ('manipulate', 'ADP'),
#   ('Carbide', 'ADP'),
#   ('planned', 'VERB'),
#   ('gilt', 'ADP'),
#   ('more', 'ADV'),
#   ('recovering', 'ADP'),
#   ('parishioners', 'ADP'),
#   ('Angels', 'ADP'),
#   ('chat', 'ADP'),
#   ('low-ball', 'ADP'),
#   ('purchasing', 'NOUN'),
#   ('confident', 'ADP'),
#   ('creditworthiness', 'ADP'),
#   ('rebuffed', 'ADP'),
#   ('study', 'NOUN'),
#   ('*T*-169', 'ADP'),
#   ('buy', 'NOUN'),
#   ('more', 'ADJ'),
#   ('knowledgeable', 'ADP'),
#   ('ago', 'ADP'),
#   ('implicit', 'ADP'),
#   ('Japanese', 'ADJ'),
#   ('Yet', 'CONJ'),
#   ('Wilmington', 'ADP'),
#   ('neoprene', 'ADP'),
#   ('rubber', 'ADP'),
#   ('supreme', 'ADP'),
#   ('Deng', 'ADP'),
#   ('Xiaoping', 'ADP'),
#   ('Frankly', 'ADP'),
#   ('speaking', 'ADP'),
#   ('*-146', 'ADP'),
#   ('deeply', 'ADP'),
#   ('counterrevolutionary', 'ADP'),
#   ('rebellion', 'ADP'),
#   ('*T*-243', 'ADP'),
#   ('long', 'ADJ'),
#   ('ago', 'ADP'),
#   ('forecast', 'NOUN'),
#   ('rise', 'VERB'),
#   ('5.4', 'ADP'),
#   ('disaffected', 'ADP'),
#   ('hard-drinking', 'ADP'),
#   ('nearly-30', 'ADP'),
#   ('sets', 'NOUN'),
#   ('snow', 'ADP'),
#   ('search', 'ADP'),
#   ('elusive', 'ADP'),
#   ('sheep', 'ADP'),
#   ('back', 'ADV'),
#   ('behest', 'ADP'),
#   ('sinister', 'ADP'),
#   ('erudite', 'ADP'),
#   ('mobster', 'ADP'),
#   ('C.J.B.', 'ADP'),
#   ('nearby', 'ADV'),
#   ('stairs', 'ADP'),
#   ('that', 'ADP'),
#   ('*-138', 'ADP'),
#   ('altar', 'ADP'),
#   ('right', 'NOUN'),
#   ('minute', 'ADJ'),
#   ('that', 'ADP'),
#   ('*T*-146', 'ADP'),
#   ('Stark', 'ADP'),
#   ('Robertson', 'ADP'),
#   ('Stephens', 'ADP'),
#   ('circuit-breaker', 'ADP'),
#   ('aggravated', 'ADP'),
#   ('directing', 'ADP'),
#   ('selling', 'NOUN'),
#   ('less', 'ADJ'),
#   ('index-arbitrage', 'ADJ'),
#   ('*-161', 'ADP'),
#   ('Barfield', 'ADP'),
#   ('Assurance', 'ADP'),
#   ('*T*-258', 'ADP'),
#   ('manages', 'ADP'),
#   ('23.72', 'ADP'),
#   ('broadly', 'ADP'),
#   ('construed', 'ADP'),
#   ('emasculate', 'ADP'),
#   ('swallow', 'ADP'),
#   ('forcing', 'ADJ'),
#   ('sites', 'ADP'),
#   ('labor-intensive', 'ADP'),
#   ('excess', 'NOUN'),
#   ('most', 'ADJ'),
#   ('earliest', 'ADP'),
#   ('pension-fund', 'ADP'),
#   ('steadily', 'ADP'),
#   ('dwindling', 'ADP'),
#   ('strong-willed', 'ADP'),
#   ('pressing', 'ADP'),
#   ('strong-willed', 'ADP'),
#   ('non-religious', 'ADP'),
#   ('drag-down', 'ADP'),
#   ('chaotic', 'ADP'),
#   ('trap', 'ADP'),
#   ('unwary', 'ADP'),
#   ('quantitative', 'ADP'),
#   ('interior', 'ADP'),
#   ('decorator', 'ADP'),
#   ('spook', 'ADP'),
#   ('sprawling', 'ADP'),
#   ('balkanized', 'ADP'),
#   ('mammoth', 'ADP'),
#   ('target', 'NOUN'),
#   ('Bellows', 'ADP'),
#   ('brightened', 'ADP'),
#   ('Image', 'ADP'),
#   ('*T*-170', 'ADP'),
#   ('*T*-171', 'ADP'),
#   ('*-100', 'ADP'),
#   ('Delaware', 'ADP'),
#   ('Dunkin', 'ADP'),
#   ('plans', 'VERB'),
#   ('deter', 'ADP'),
#   ('unworkable', 'ADP'),
#   ('executive', 'NOUN'),
#   ('unfunded', 'ADP'),
#   ('sign', 'NOUN'),
#   ('assert', 'ADP'),
#   ('restricting', 'ADP'),
#   ('context', 'ADP'),
#   ('characterized', 'ADP'),
#   ('excise', 'ADJ'),
#   ('that', 'ADP'),
#   ('objectionable', 'ADP'),
#   ('conflict', 'ADP'),
#   ('clear', 'ADJ'),
#   ('sell-off', 'ADP'),
#   ('Factories', 'ADP'),
#   ('booked', 'ADP'),
#   ('236.74', 'ADP'),
#   ('236.79', 'ADP'),
#   ('commercial', 'NOUN'),
#   ('distasteful', 'ADP'),
#   ('more', 'ADJ'),
#   ('newsworthy', 'ADP'),
#   ('Chinese', 'ADJ'),
#   ('undiplomatic', 'ADP'),
#   ('fashion', 'ADP'),
#   ('up', 'ADV'),
#   ('dismiss', 'ADP'),
#   ('sentimental', 'ADP'),
#   ('housing-assistance', 'ADP'),
#   ('sleeping', 'ADP'),
#   ('Reagan-Bush', 'ADP'),
#   ('report', 'VERB'),
#   ('journal', 'ADP'),
#   ('Nature', 'ADP'),
#   ('occurrences', 'ADP'),
#   ('help', 'VERB'),
#   ('revising', 'ADP'),
#   ('credit-rating', 'ADP'),
#   ('that', 'DET'),
#   ('forthcoming', 'ADP'),
#   ('10-year', 'ADJ'),
#   ('yen-denominated', 'ADP'),
#   ('about', 'ADP'),
#   ('redeeming', 'ADP'),
#   ('pretax', 'ADJ'),
#   ('like', 'ADP'),
#   ('14.75', 'ADP'),
#   ('most', 'ADJ'),
#   ('57.7', 'ADP'),
#   ('that', 'ADP'),
#   ('that', 'ADP'),
#   ('Sable', 'ADP'),
#   ('early', 'ADJ'),
#   ('experiencing', 'ADP'),
#   ('milked', 'ADP'),
#   ('*-117', 'ADP'),
#   ('as', 'ADP'),
#   ('principal', 'NOUN'),
#   ('fights', 'ADP'),
#   ('rechargeable', 'ADP'),
#   ('cadmium', 'ADP'),
#   ('carbon', 'ADP'),
#   ('zinc', 'ADP'),
#   ('movies', 'ADP'),
#   ('Peck', 'ADP'),
#   ('marvelously', 'ADP'),
#   ('loose', 'ADP'),
#   ('energetic', 'ADP'),
#   ('portrayal', 'ADP'),
#   ('Test-preparation', 'ADP'),
#   ('subindustry', 'ADP'),
#   ('grower', 'ADP'),
#   ('climb', 'ADP'),
#   ('566.54', 'ADP'),
#   ('forecast', 'NOUN'),
#   ('28.53', 'ADP'),
#   ('Derel', 'ADP'),
#   ('Adams', 'ADP'),
#   ('Killeen', 'ADP'),
#   ('Francis', 'ADP'),
#   ('Angier', 'ADP'),
#   ('Reddington', 'ADP'),
#   ('Shores', 'ADP'),
#   ('Arlington', 'ADP'),
#   ('Stirlen', 'ADP'),
#   ('Arlington', 'ADP'),
#   ('Bonnell', 'ADP'),
#   ('Boorse', 'ADP'),
#   ('Horsham', 'ADP'),
#   ('Chiodo', 'ADP'),
#   ('Camille', 'ADP'),
#   ('Chafic', 'ADP'),
#   ('Cotran', 'ADP'),
#   ('aiming', 'ADP'),
#   ('elderly', 'ADP'),
#   ('tall', 'ADP'),
#   ('energetic', 'ADP'),
#   ('much', 'ADV'),
#   ('sounds', 'NOUN'),
#   ('neat', 'ADP'),
#   ('propagandizes', 'ADP'),
#   ('brilliantly', 'ADP'),
#   ('Holt', 'ADP'),
#   ('326', 'ADP'),
#   ('19.95', 'ADP'),
#   ('detailed', 'ADJ'),
#   ('reassuring', 'ADP'),
#   ('plaintive', 'ADP'),
#   ('high-minded', 'ADP'),
#   ('assurance', 'ADP'),
#   ('reading', 'NOUN'),
#   ('sticky', 'ADP'),
#   ('fingers', 'ADP'),
#   ('sweaty', 'ADP'),
#   ('rhythmically', 'ADP'),
#   ('that', 'ADP'),
#   ('*T*-220', 'ADP'),
#   ('first', 'ADJ'),
#   ('1614', 'ADP'),
#   ('out', 'PRT'),
#   ('FreudToy', 'ADP'),
#   ('pillow', 'ADP'),
#   ('bearing', 'NOUN'),
#   ('likeness', 'ADP'),
#   ('Sigmund', 'ADP'),
#   ('Freud', 'ADP'),
#   ('24.95', 'ADP'),
#   ('tool', 'ADP'),
#   ('do-it-yourself', 'ADP'),
#   ('Packages', 'ADP'),
#   ('rewarding', 'ADP'),
#   ('Colorliner', 'ADP'),
#   ('newspaper-printing', 'ADP'),
#   ('call', 'VERB'),
#   ('happened', 'ADP'),
#   ('Islamabad', 'ADP'),
#   ('237-seat', 'ADP'),
#   ('rigged', 'ADP'),
#   ('Continental', 'ADP'),
#   ('Baking', 'ADP'),
#   ('bread', 'ADP'),
#   ('commercial', 'ADJ'),
#   ('Squier', 'ADP'),
#   ('mean', 'VERB'),
#   ('dirty', 'ADP'),
#   ('that', 'ADP'),
#   ('tailor-made', 'ADP'),
#   ('more', 'ADV'),
#   ('earlier', 'ADV'),
#   ('adopt', 'ADP'),
#   ('importer', 'ADP'),
#   ('7.40', 'ADP'),
#   ('7.45', 'ADP'),
#   ('7.40', 'ADP'),
#   ('7.50', 'ADP'),
#   ('ASLACTON', 'ADP'),
#   ('11,390,000', 'ADP'),
#   ('payable', 'ADP'),
#   ('Jan.', 'ADP'),
#   ("'s", 'PRT'),
#   ('walking', 'ADP'),
#   ('display', 'ADP'),
#   ('projector', 'ADP'),
#   ('underline', 'ADP'),
#   ('234.4', 'ADP'),
#   ('5.4', 'ADP'),
#   ('Wa', '.'),
#   ('Japanese', 'ADJ'),
#   ('carrying', 'ADP'),
#   ('sensitivity', 'ADP'),
#   ('55-a-share', 'ADP'),
#   ('bid', 'VERB'),
#   ('that', 'ADP'),
#   ('steps', 'NOUN'),
#   ('Fourteen', 'ADP'),
#   ('jurisdiction', 'ADP'),
#   ('EEOC', 'ADP'),
#   ('judgment', 'ADP'),
#   ('Precious', 'ADP'),
#   ('influenced', 'ADP'),
#   ('more', 'ADV'),
#   ("O'Neill", 'ADP'),
#   ('Elders', 'ADP'),
#   ('junk', 'NOUN'),
#   ('innovative', 'ADP'),
#   ('market-based', 'ADP'),
#   ('trading', 'NOUN'),
#   ('polluters', 'ADP'),
#   ('McCabe', 'ADP'),
#   ('materialized', 'ADP'),
#   ('stream', 'ADP'),
#   ('tire-kickers', 'ADP'),
#   ('lookee-loos', 'ADP'),
#   ('modification', 'ADP'),
#   ('*-130', 'ADP'),
#   ('opening', 'NOUN'),
#   ('issuers', 'ADP'),
#   ('IOUs', 'ADP'),
#   ('public-relations', 'ADP'),
#   ('that', 'ADP'),
#   ('sends', 'ADP'),
#   ('stuff', 'ADP'),
#   ('Alstyne', 'ADP'),
#   ('notes', 'NOUN'),
#   ('apple', 'ADP'),
#   ('apples', 'ADP'),
#   ('close', 'NOUN'),
#   ('watch', 'VERB'),
#   ('away', 'ADV'),
#   ('incest', 'ADP'),
#   ('transforming', 'ADP'),
#   ('PORTING', 'ADP'),
#   ('POTABLES', 'ADP'),
#   ('Scypher', 'ADP'),
#   ('Cup-Tote', 'ADP'),
#   ('overdone', 'ADP'),
#   ('reversal', 'ADP'),
#   ('which', 'DET'),
#   ('earlier', 'ADV'),
#   ('agreed', 'VERB'),
#   ('supply', 'NOUN'),
#   ('more', 'ADV'),
#   ('Backer', 'ADP'),
#   ('Spielvogel', 'ADP'),
#   ('Bates', 'ADP'),
#   ('colony', 'ADP'),
#   ('surveyed', 'ADP'),
#   ('Short', 'ADP'),
#   ('total', 'ADJ'),
#   ('middle-ground', 'ADP'),
#   ('away', 'ADV'),
#   ('enjoy', 'ADP'),
#   ('industrial-production', 'ADP'),
#   ('standard', 'ADJ'),
#   ('Yet', 'CONJ'),
#   ('executive', 'NOUN'),
#   ('appropriation', 'ADP'),
#   ('filling', 'VERB'),
#   ('double', 'ADJ'),
#   ('page-one', 'NOUN'),
#   ('Western', 'ADJ'),
#   ('Western', 'ADJ'),
#   ('down', 'ADV'),
#   ('Alexander', 'ADP'),
#   ('Graham', 'ADP'),
#   ('offer', 'VERB'),
#   ('invention', 'ADP'),
#   ('communication', 'ADP'),
#   ('telegraph', 'VERB'),
#   ('if', 'ADP'),
#   ('pride', 'ADP'),
#   ('captive', 'ADP'),
#   ('audience', 'ADP'),
#   ('*T*-204', 'ADP'),
#   ('less', 'ADJ'),
#   ('Gringo', 'ADP'),
#   ('confused', 'VERB'),
#   ('rendering', 'ADP'),
#   ('Fuentes', 'ADP'),
#   ('Mexican', 'ADP'),
#   ('Revolution', 'ADP'),
#   ('AN', 'ADP'),
#   ('EXCHANGE', 'ADP'),
#   ('change', 'VERB'),
#   ('trading', 'NOUN'),
#   ('Academically', 'ADP'),
#   ('disparate', 'ADP'),
#   ('split', 'VERB'),
#   ('privileged', 'ADP'),
#   ('elite', 'ADP'),
#   ('monied', 'ADP'),
#   ('neighborhoods', 'ADP'),
#   ('inner', 'ADP'),
#   ('neighborhoods', 'ADP'),
#   ('reinstating', 'ADP'),
#   ('Choose', 'ADP'),
#   ('out', 'PRT'),
#   ('deprived', 'ADP'),
#   ('families', 'ADP'),
#   ('name', 'VERB'),
#   ('Billings', 'ADP'),
#   ('*T*-155', 'ADP'),
#   ('serviced', 'ADP'),
#   ('replicated', 'ADP'),
#   ('*T*-252', 'ADP'),
#   ('complaining', 'ADP'),
#   ('up', 'ADV'),
#   ('ratepayers', 'ADP'),
#   ('overruns', 'ADP'),
#   ('*-120', 'ADP'),
#   ('battle', 'NOUN'),
#   ('floors', 'ADP'),
#   ('sketching', 'ADP'),
#   ('passers-by', 'ADP'),
#   ('up', 'ADV')]]

# %% [markdown]
# ##### Unigram tagger for incorrect tagged words

# %%
# Using unigram tagger to validate incorrect tags we got from Vanilla viterbi
unigram_tagger = nltk.UnigramTagger(train_set)
unigram_tagger.evaluate(incorrect_tag_word)
# Out:
# 0.19856887298747763

# %%
unigram_tagger.tag(incorrect_word)
# Out:
# [('rule', 'NOUN'),
#  ("D'Amico", None),
#  ('slow', 'VERB'),
#  ('computerize', None),
#  ('target', 'NOUN'),
#  ('niches', None),
#  ('*T*-199', None),
#  ('rates', 'NOUN'),
#  ('study', 'NOUN'),
#  ('waive', None),
#  ('protective', None),
#  ('golden', None),
#  ('biscuit', None),
#  ('Lazzaroni', None),
#  ('overproduction', None),
#  ('so', 'ADV'),
#  ('lieutenant', None),
#  ('Fishman', None),
#  ('Longwood', None),
#  ('Floyd', None),
#  ('Amin', None),
#  ('Jalaalwalikraam', None),
#  ('Glenham', None),
#  ('Knapp', None),
#  ('Deborah', None),
#  ('Renee', None),
#  ('Francis', None),
#  ('Muscolina', None),
#  ('Palisades', None),
#  ('Najarian', None),
#  ('Minn.', None),
#  ('Norwick', None),
#  ('Nesconset', None),
#  ('views', 'NOUN'),
#  ('IRAs', None),
#  ('Output', None),
#  ('gradually', None),
#  ('reaches', None),
#  ('Pakistan', None),
#  ('Bhutto', None),
#  ('defeated', None),
#  ('no-confidence', None),
#  ('42-year', None),
#  ('that', 'ADP'),
#  ('down', 'ADV'),
#  ('11-month-old', None),
#  ('Absorbed', None),
#  ('doling', None),
#  ('out', 'PRT'),
#  ('tidbits', None),
#  ('gloss', None),
#  ('root', None),
#  ('A', 'DET'),
#  ('auspices', None),
#  ('South', 'NOUN'),
#  ('African', 'ADJ'),
#  ('Items', None),
#  ('numbered', None),
#  ('about', 'ADP'),
#  ('newcomer', None),
#  ('powder', None),
#  ('that', 'ADP'),
#  ('*T*-119', None),
#  ('expires', None),
#  ('more', 'ADJ'),
#  ('realestate', None),
#  ('will', 'VERB'),
#  ('Topix', None),
#  ('16.05', None),
#  ('1.46', None),
#  ('0.05', None),
#  ('2691.19', None),
#  ('imagine', None),
#  ('racing', None),
#  ('Chicago-style', None),
#  ('arbitrager', None),
#  ('that', 'ADP'),
#  ('*T*-227', None),
#  ('stays', None),
#  ('ABORTION', None),
#  ('RULING', None),
#  ('UPHELD', None),
#  ('equipped', None),
#  ('*-90', None),
#  ('front-seat', None),
#  ('headrests', None),
#  ('*-91', None),
#  ('16\\/32', None),
#  ('Ind.', None),
#  ('arched', None),
#  ('G', None),
#  ('Show', None),
#  ('around', 'ADP'),
#  ('Huxtable', None),
#  ('viewers', None),
#  ('laughing', 'ADJ'),
#  ('interjects', None),
#  ('interrogated', None),
#  ('rapists', None),
#  ('Conn.based', None),
#  ('magnified', None),
#  ('nonrecurring', None),
#  ('8.2', None),
#  ('asset-valuation', None),
#  ('adjustments', None),
#  ('that', 'ADP'),
#  ('as', 'ADP'),
#  ('troublesome', None),
#  ('Given', None),
#  ('that', 'ADP'),
#  ('overpaying', None),
#  ('about', 'ADP'),
#  ('crossed', None),
#  ('gauging', None),
#  ('early', 'ADJ'),
#  ('63.79', None),
#  ('35500.64', None),
#  ('Contra', None),
#  ('command', 'VERB'),
#  ('Honduras', None),
#  ('Sandinista', None),
#  ('offensive', None),
#  ('rebel', None),
#  ('57.6', None),
#  ('Yorkers', None),
#  ('watch', 'VERB'),
#  ('viewership', None),
#  ('Impact', None),
#  ('Columbus', None),
#  ('that', 'ADP'),
#  ('diversified', 'ADJ'),
#  ('that', 'ADP'),
#  ('impressive', None),
#  ('*T*-182', None),
#  ('combat', None),
#  ('import', 'NOUN'),
#  ('worth', 'NOUN'),
#  ('that', 'ADP'),
#  ('that', 'ADP'),
#  ('1,200', None),
#  ('Mogavero', None),
#  ('Piscataway', None),
#  ('eight-count', None),
#  ('indictment', None),
#  ('Vice', None),
#  ('Sherwin', None),
#  ('manipulate', None),
#  ('Carbide', None),
#  ('planned', 'VERB'),
#  ('gilt', None),
#  ('more', 'ADJ'),
#  ('recovering', None),
#  ('parishioners', None),
#  ('Angels', None),
#  ('chat', None),
#  ('low-ball', None),
#  ('purchasing', 'VERB'),
#  ('confident', None),
#  ('creditworthiness', None),
#  ('rebuffed', None),
#  ('study', 'NOUN'),
#  ('*T*-169', None),
#  ('buy', 'VERB'),
#  ('more', 'ADJ'),
#  ('knowledgeable', None),
#  ('ago', 'ADP'),
#  ('implicit', None),
#  ('Japanese', 'ADJ'),
#  ('Yet', 'CONJ'),
#  ('Wilmington', None),
#  ('neoprene', None),
#  ('rubber', None),
#  ('supreme', None),
#  ('Deng', None),
#  ('Xiaoping', None),
#  ('Frankly', None),
#  ('speaking', None),
#  ('*-146', None),
#  ('deeply', None),
#  ('counterrevolutionary', None),
#  ('rebellion', None),
#  ('*T*-243', None),
#  ('long', 'ADJ'),
#  ('ago', 'ADP'),
#  ('forecast', 'NOUN'),
#  ('rise', 'VERB'),
#  ('5.4', None),
#  ('disaffected', None),
#  ('hard-drinking', None),
#  ('nearly-30', None),
#  ('sets', 'NOUN'),
#  ('snow', None),
#  ('search', None),
#  ('elusive', None),
#  ('sheep', None),
#  ('back', 'ADV'),
#  ('behest', None),
#  ('sinister', None),
#  ('erudite', None),
#  ('mobster', None),
#  ('C.J.B.', None),
#  ('nearby', 'ADV'),
#  ('stairs', None),
#  ('that', 'ADP'),
#  ('*-138', None),
#  ('altar', None),
#  ('right', 'NOUN'),
#  ('minute', 'NOUN'),
#  ('that', 'ADP'),
#  ('*T*-146', None),
#  ('Stark', None),
#  ('Robertson', None),
#  ('Stephens', None),
#  ('circuit-breaker', None),
#  ('aggravated', None),
#  ('directing', None),
#  ('selling', 'VERB'),
#  ('less', 'ADJ'),
#  ('index-arbitrage', 'ADJ'),
#  ('*-161', None),
#  ('Barfield', None),
#  ('Assurance', None),
#  ('*T*-258', None),
#  ('manages', None),
#  ('23.72', None),
#  ('broadly', None),
#  ('construed', None),
#  ('emasculate', None),
#  ('swallow', None),
#  ('forcing', 'ADJ'),
#  ('sites', None),
#  ('labor-intensive', None),
#  ('excess', 'ADJ'),
#  ('most', 'ADJ'),
#  ('earliest', None),
#  ('pension-fund', None),
#  ('steadily', None),
#  ('dwindling', None),
#  ('strong-willed', None),
#  ('pressing', None),
#  ('strong-willed', None),
#  ('non-religious', None),
#  ('drag-down', None),
#  ('chaotic', None),
#  ('trap', None),
#  ('unwary', None),
#  ('quantitative', None),
#  ('interior', None),
#  ('decorator', None),
#  ('spook', None),
#  ('sprawling', None),
#  ('balkanized', None),
#  ('mammoth', None),
#  ('target', 'NOUN'),
#  ('Bellows', None),
#  ('brightened', None),
#  ('Image', None),
#  ('*T*-170', None),
#  ('*T*-171', None),
#  ('*-100', None),
#  ('Delaware', None),
#  ('Dunkin', None),
#  ('plans', 'VERB'),
#  ('deter', None),
#  ('unworkable', None),
#  ('executive', 'NOUN'),
#  ('unfunded', None),
#  ('sign', 'NOUN'),
#  ('assert', None),
#  ('restricting', None),
#  ('context', None),
#  ('characterized', None),
#  ('excise', 'ADJ'),
#  ('that', 'ADP'),
#  ('objectionable', None),
#  ('conflict', None),
#  ('clear', 'ADJ'),
#  ('sell-off', None),
#  ('Factories', None),
#  ('booked', None),
#  ('236.74', None),
#  ('236.79', None),
#  ('commercial', 'ADJ'),
#  ('distasteful', None),
#  ('more', 'ADJ'),
#  ('newsworthy', None),
#  ('Chinese', 'ADJ'),
#  ('undiplomatic', None),
#  ('fashion', None),
#  ('up', 'PRT'),
#  ('dismiss', None),
#  ('sentimental', None),
#  ('housing-assistance', None),
#  ('sleeping', None),
#  ('Reagan-Bush', None),
#  ('report', 'NOUN'),
#  ('journal', None),
#  ('Nature', None),
#  ('occurrences', None),
#  ('help', 'VERB'),
#  ('revising', None),
#  ('credit-rating', None),
#  ('that', 'ADP'),
#  ('forthcoming', None),
#  ('10-year', 'ADJ'),
#  ('yen-denominated', None),
#  ('about', 'ADP'),
#  ('redeeming', None),
#  ('pretax', 'NOUN'),
#  ('like', 'ADP'),
#  ('14.75', None),
#  ('most', 'ADJ'),
#  ('57.7', None),
#  ('that', 'ADP'),
#  ('that', 'ADP'),
#  ('Sable', None),
#  ('early', 'ADJ'),
#  ('experiencing', None),
#  ('milked', None),
#  ('*-117', None),
#  ('as', 'ADP'),
#  ('principal', 'NOUN'),
#  ('fights', None),
#  ('rechargeable', None),
#  ('cadmium', None),
#  ('carbon', None),
#  ('zinc', None),
#  ('movies', None),
#  ('Peck', None),
#  ('marvelously', None),
#  ('loose', None),
#  ('energetic', None),
#  ('portrayal', None),
#  ('Test-preparation', None),
#  ('subindustry', None),
#  ('grower', None),
#  ('climb', None),
#  ('566.54', None),
#  ('forecast', 'NOUN'),
#  ('28.53', None),
#  ('Derel', None),
#  ('Adams', None),
#  ('Killeen', None),
#  ('Francis', None),
#  ('Angier', None),
#  ('Reddington', None),
#  ('Shores', None),
#  ('Arlington', None),
#  ('Stirlen', None),
#  ('Arlington', None),
#  ('Bonnell', None),
#  ('Boorse', None),
#  ('Horsham', None),
#  ('Chiodo', None),
#  ('Camille', None),
#  ('Chafic', None),
#  ('Cotran', None),
#  ('aiming', None),
#  ('elderly', None),
#  ('tall', None),
#  ('energetic', None),
#  ('much', 'ADV'),
#  ('sounds', 'NOUN'),
#  ('neat', None),
#  ('propagandizes', None),
#  ('brilliantly', None),
#  ('Holt', None),
#  ('326', None),
#  ('19.95', None),
#  ('detailed', 'ADJ'),
#  ('reassuring', None),
#  ('plaintive', None),
#  ('high-minded', None),
#  ('assurance', None),
#  ('reading', 'NOUN'),
#  ('sticky', None),
#  ('fingers', None),
#  ('sweaty', None),
#  ('rhythmically', None),
#  ('that', 'ADP'),
#  ('*T*-220', None),
#  ('first', 'ADJ'),
#  ('1614', None),
#  ('out', 'PRT'),
#  ('FreudToy', None),
#  ('pillow', None),
#  ('bearing', 'NOUN'),
#  ('likeness', None),
#  ('Sigmund', None),
#  ('Freud', None),
#  ('24.95', None),
#  ('tool', None),
#  ('do-it-yourself', None),
#  ('Packages', None),
#  ('rewarding', None),
#  ('Colorliner', None),
#  ('newspaper-printing', None),
#  ('call', 'VERB'),
#  ('happened', None),
#  ('Islamabad', None),
#  ('237-seat', None),
#  ('rigged', None),
#  ('Continental', None),
#  ('Baking', None),
#  ('bread', None),
#  ('commercial', 'ADJ'),
#  ('Squier', None),
#  ('mean', 'VERB'),
#  ('dirty', None),
#  ('that', 'ADP'),
#  ('tailor-made', None),
#  ('more', 'ADJ'),
#  ('earlier', 'ADJ'),
#  ('adopt', None),
#  ('importer', None),
#  ('7.40', None),
#  ('7.45', None),
#  ('7.40', None),
#  ('7.50', None),
#  ('ASLACTON', None),
#  ('11,390,000', None),
#  ('payable', None),
#  ('Jan.', None),
#  ("'s", 'PRT'),
#  ('walking', None),
#  ('display', None),
#  ('projector', None),
#  ('underline', None),
#  ('234.4', None),
#  ('5.4', None),
#  ('Wa', 'NOUN'),
#  ('Japanese', 'ADJ'),
#  ('carrying', None),
#  ('sensitivity', None),
#  ('55-a-share', None),
#  ('bid', 'NOUN'),
#  ('that', 'ADP'),
#  ('steps', 'NOUN'),
#  ('Fourteen', None),
#  ('jurisdiction', None),
#  ('EEOC', None),
#  ('judgment', None),
#  ('Precious', None),
#  ('influenced', None),
#  ('more', 'ADJ'),
#  ("O'Neill", None),
#  ('Elders', None),
#  ('junk', 'NOUN'),
#  ('innovative', None),
#  ('market-based', None),
#  ('trading', 'NOUN'),
#  ('polluters', None),
#  ('McCabe', None),
#  ('materialized', None),
#  ('stream', None),
#  ('tire-kickers', None),
#  ('lookee-loos', None),
#  ('modification', None),
#  ('*-130', None),
#  ('opening', 'VERB'),
#  ('issuers', None),
#  ('IOUs', None),
#  ('public-relations', None),
#  ('that', 'ADP'),
#  ('sends', None),
#  ('stuff', None),
#  ('Alstyne', None),
#  ('notes', 'NOUN'),
#  ('apple', None),
#  ('apples', None),
#  ('close', 'NOUN'),
#  ('watch', 'VERB'),
#  ('away', 'ADV'),
#  ('incest', None),
#  ('transforming', None),
#  ('PORTING', None),
#  ('POTABLES', None),
#  ('Scypher', None),
#  ('Cup-Tote', None),
#  ('overdone', None),
#  ('reversal', None),
#  ('which', 'DET'),
#  ('earlier', 'ADJ'),
#  ('agreed', 'VERB'),
#  ('supply', 'NOUN'),
#  ('more', 'ADJ'),
#  ('Backer', None),
#  ('Spielvogel', None),
#  ('Bates', None),
#  ('colony', None),
#  ('surveyed', None),
#  ('Short', None),
#  ('total', 'ADJ'),
#  ('middle-ground', None),
#  ('away', 'ADV'),
#  ('enjoy', None),
#  ('industrial-production', None),
#  ('standard', 'ADJ'),
#  ('Yet', 'CONJ'),
#  ('executive', 'NOUN'),
#  ('appropriation', None),
#  ('filling', 'VERB'),
#  ('double', 'ADJ'),
#  ('page-one', 'NOUN'),
#  ('Western', 'ADJ'),
#  ('Western', 'ADJ'),
#  ('down', 'ADV'),
#  ('Alexander', None),
#  ('Graham', None),
#  ('offer', 'NOUN'),
#  ('invention', None),
#  ('communication', None),
#  ('telegraph', 'VERB'),
#  ('if', 'ADP'),
#  ('pride', None),
#  ('captive', None),
#  ('audience', None),
#  ('*T*-204', None),
#  ('less', 'ADJ'),
#  ('Gringo', None),
#  ('confused', 'VERB'),
#  ('rendering', None),
#  ('Fuentes', None),
#  ('Mexican', None),
#  ('Revolution', None),
#  ('AN', None),
#  ('EXCHANGE', None),
#  ('change', 'NOUN'),
#  ('trading', 'NOUN'),
#  ('Academically', None),
#  ('disparate', None),
#  ('split', 'VERB'),
#  ('privileged', None),
#  ('elite', None),
#  ('monied', None),
#  ('neighborhoods', None),
#  ('inner', None),
#  ('neighborhoods', None),
#  ('reinstating', None),
#  ('Choose', None),
#  ('out', 'PRT'),
#  ('deprived', None),
#  ('families', None),
#  ('name', 'NOUN'),
#  ('Billings', None),
#  ('*T*-155', None),
#  ('serviced', None),
#  ('replicated', None),
#  ('*T*-252', None),
#  ('complaining', None),
#  ('up', 'PRT'),
#  ('ratepayers', None),
#  ('overruns', None),
#  ('*-120', None),
#  ('battle', 'NOUN'),
#  ('floors', None),
#  ('sketching', None),
#  ('passers-by', None),
#  ('up', 'PRT')]

# %% [markdown]
# ***Getting 16- 17% accuracy with only unigram

# %% [markdown]
# ##### Regex tagger for incorrect tagged words

# %%
# Using Regex tagger to check incorrect tags we got from Vanilla viterbi
patterns = [
    (r'.*ing$', 'VERB'),
    (r'.*ed$', 'VERB'),  
    (r'.*es$', 'VERB'),
    (r'.*ould$', 'VERB'), 
    (r'.*\'s$', 'PRT'),               
    (r'.*s$', 'NOUN'), 
    (r'^-?[0-9]+(.[0-9]+)?$', 'NUM'),
    (r'.*', 'NOUN')
]

regexp_tagger = nltk.RegexpTagger(patterns)

regexp_tagger.evaluate(incorrect_tag_word)
# Out:
# 0.055456171735241505

# %% [markdown]
# ***Getting very low accuracy with only regex

# %% [markdown]
# #### Combining both unigram and regex tagger and check on full test set and incorrect tags got from vanilla viterbi

# %% [markdown]
# ##### Validation on test set

# %%
rule_based_tagger = nltk.RegexpTagger(patterns)

# lexicon backed up by the rule-based tagger
lexicon_tagger = nltk.UnigramTagger(train_set, backoff=rule_based_tagger)

lexicon_tagger.evaluate(test_run)
# Out:
# 0.96875

# %% [markdown]
# **Giving 97% accuracy on full test set

# %% [markdown]
# ##### Validation on incorrect tagged words we got from Vanilla Viterbi

# %%
rule_based_tagger = nltk.RegexpTagger(patterns)

# lexicon backed up by the rule-based tagger
lexicon_tagger = nltk.UnigramTagger(train_set, backoff=rule_based_tagger)

lexicon_tagger.evaluate(incorrect_tag_word)
# Out:
# 0.19856887298747763

# %% [markdown]
# **Overall accuaracy is 16% on wrongly tagged data

# %% [markdown]
# ### Adding Unigram and regex to Viterbi code

# %%
def Viterbi_modified_2(words, train_bag = train_tagged_words):
    # Viterbi Heuristic
    state = []
    T = list(set([pair[1] for pair in train_bag]))
    patterns = [
    (r'.*ing$', 'VERB'),
    (r'.*ed$', 'VERB'),  
    (r'.*es$', 'VERB'),
    (r'.*ould$', 'VERB'), 
    (r'.*\'s$', 'PRT'),               
    (r'.*s$', 'NOUN'), 
    (r'^-?[0-9]+(.[0-9]+)?$', 'NUM'),
    (r'.*', 'NOUN')]

    regexp_tagger = nltk.RegexpTagger(patterns)

# lexicon backed up by the rule-based tagger
    lexicon_tagger = nltk.UnigramTagger(train_set, backoff=regexp_tagger)

    #lexicon_tagger.evaluate(incorrect_tag_word
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in T:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]
            state_probability = emission_p * transition_p    
            p.append(state_probability)
            
        pmax = max(p)
        state_max = T[p.index(pmax)]
        #state_max = []
        if (pmax == 0):
            
            new_tag = lexicon_tagger.tag((word,state_max))
            
            state_max = new_tag[0][1]
            
        state.append(state_max)
    return list(zip(words, state))

# %% [markdown]
# #### Evaluating tagging accuracy

# %%
start = time.time()
tagged_seq_2 = Viterbi_modified_2(test_tagged_words)
end = time.time()
print('Time required for execution:',end - start)
# Out:
# Time required for execution: 1098.988477230072

# %%
check_2 = [i for i, j in zip(tagged_seq_2, test_run_base) if i == j]
print(len(check_2))
print(len(test_run_base))
print(len(tagged_seq_2))
# Out:
# 4815
# 5121
# 5121

# %%
accuracy = len(check_2)/len(tagged_seq_2)
accuracy
# Out:
# 0.9402460456942003

# %%
incorrect_tagged_cases_2 = [[test_run_base[i-1],j] for i, j in enumerate(zip(tagged_seq_2, test_run_base)) if j[0]!=j[1]]
len(incorrect_tagged_cases_2)
# Out:
# 306

# %% [markdown]
# ### Accuracy is enhanced to 94 - 95%

# %% [markdown]
# ### Validation set performance with method 2

# %%
validation_tokens
# Out:
# ['Android',
#  'is',
#  'a',
#  'mobile',
#  'operating',
#  'system',
#  'developed',
#  'by',
#  'Google',
#  '.',
#  'Android',
#  'has',
#  'been',
#  'the',
#  'best-selling',
#  'OS',
#  'worldwide',
#  'on',
#  'smartphones',
#  'since',
#  '2011',
#  'and',
#  'on',
#  'tablets',
#  'since',
#  '2013',
#  '.',
#  'Google',
#  'and',
#  'Twitter',
#  'made',
#  'a',
#  'deal',
#  'in',
#  '2015',
#  'that',
#  'gave',
#  'Google',
#  'access',
#  'to',
#  'Twitter',
#  "'s",
#  'firehose',
#  '.',
#  'Twitter',
#  'is',
#  'an',
#  'online',
#  'news',
#  'and',
#  'social',
#  'networking',
#  'service',
#  'on',
#  'which',
#  'users',
#  'post',
#  'and',
#  'interact',
#  'with',
#  'messages',
#  'known',
#  'as',
#  'tweets',
#  '.',
#  'Before',
#  'entering',
#  'politics',
#  ',',
#  'Donald',
#  'Trump',
#  'was',
#  'a',
#  'domineering',
#  'businessman',
#  'and',
#  'a',
#  'television',
#  'personality',
#  '.',
#  'The',
#  '2018',
#  'FIFA',
#  'World',
#  'Cup',
#  'is',
#  'the',
#  '21st',
#  'FIFA',
#  'World',
#  'Cup',
#  ',',
#  'an',
#  'international',
#  'football',
#  'tournament',
#  'contested',
#  'once',
#  'every',
#  'four',
#  'years',
#  '.',
#  'This',
#  'is',
#  'the',
#  'first',
#  'World',
#  'Cup',
#  'to',
#  'be',
#  'held',
#  'in',
#  'Eastern',
#  'Europe',
#  'and',
#  'the',
#  '11th',
#  'time',
#  'that',
#  'it',
#  'has',
#  'been',
#  'held',
#  'in',
#  'Europe',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'cheapest',
#  'round',
#  'trips',
#  'from',
#  'Dallas',
#  'to',
#  'Atlanta',
#  'I',
#  'would',
#  'like',
#  'to',
#  'see',
#  'flights',
#  'from',
#  'Denver',
#  'to',
#  'Philadelphia',
#  '.',
#  'Show',
#  'me',
#  'the',
#  'price',
#  'of',
#  'the',
#  'flights',
#  'leaving',
#  'Atlanta',
#  'at',
#  'about',
#  '3',
#  'in',
#  'the',
#  'afternoon',
#  'and',
#  'arriving',
#  'in',
#  'San',
#  'Francisco',
#  '.',
#  'NASA',
#  'invited',
#  'social',
#  'media',
#  'users',
#  'to',
#  'experience',
#  'the',
#  'launch',
#  'of',
#  'ICESAT-2',
#  'Satellite',
#  '.']

# %%
start = time.time()
tagged_seq_validation_2 = Viterbi_modified_2(validation_tokens)
end = time.time()
print('Time required for execution:',end - start)
# Out:
# Time required for execution: 39.940598249435425

# %%
tagged_seq_validation_2
# Out:
# [('Android', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('Google', 'NOUN'),
#  ('.', '.'),
#  ('Android', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('OS', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('on', 'ADP'),
#  ('smartphones', 'VERB'),
#  ('since', 'ADP'),
#  ('2011', 'NUM'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013', 'NUM'),
#  ('.', '.'),
#  ('Google', 'NOUN'),
#  ('and', 'CONJ'),
#  ('Twitter', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'NUM'),
#  ('that', 'ADP'),
#  ('gave', 'VERB'),
#  ('Google', 'NOUN'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('Twitter', 'NOUN'),
#  ("'s", 'PRT'),
#  ('firehose', 'NOUN'),
#  ('.', '.'),
#  ('Twitter', 'NOUN'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'NOUN'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'NOUN'),
#  ('with', 'ADP'),
#  ('messages', 'VERB'),
#  ('known', 'VERB'),
#  ('as', 'ADP'),
#  ('tweets', 'NOUN'),
#  ('.', '.'),
#  ('Before', 'ADP'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('Donald', 'NOUN'),
#  ('Trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'VERB'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality', 'NOUN'),
#  ('.', '.'),
#  ('The', 'DET'),
#  ('2018', 'NUM'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'NOUN'),
#  ('FIFA', 'NOUN'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('contested', 'VERB'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years', 'NOUN'),
#  ('.', '.'),
#  ('This', 'DET'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('World', 'NOUN'),
#  ('Cup', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Eastern', 'NOUN'),
#  ('Europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'ADJ'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('Europe', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('from', 'ADP'),
#  ('Dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('Atlanta', 'NOUN'),
#  ('I', 'PRON'),
#  ('would', 'VERB'),
#  ('like', 'ADP'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('Denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('Philadelphia', 'NOUN'),
#  ('.', '.'),
#  ('Show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('Atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADP'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'VERB'),
#  ('in', 'ADP'),
#  ('San', 'NOUN'),
#  ('Francisco', 'NOUN'),
#  ('.', '.'),
#  ('NASA', 'NOUN'),
#  ('invited', 'VERB'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'NOUN'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('ICESAT-2', 'NOUN'),
#  ('Satellite', 'NOUN'),
#  ('.', '.')]

# %% [markdown]
# #### Checking differently tagged words in validation set from vanilla viterbi and modified viterbi with method -2

# %%
diff_2 = [[i,j] for i,j in zip(tagged_seq_validation_2,tagged_seq_validation) if i != j]
diff_2
# Out:
# [[('Android', 'NOUN'), ('Android', 'ADP')],
#  [('Google', 'NOUN'), ('Google', 'ADP')],
#  [('Android', 'NOUN'), ('Android', 'ADP')],
#  [('OS', 'NOUN'), ('OS', 'ADP')],
#  [('worldwide', 'NOUN'), ('worldwide', 'ADP')],
#  [('smartphones', 'VERB'), ('smartphones', 'ADP')],
#  [('2011', 'NUM'), ('2011', 'ADP')],
#  [('2013', 'NUM'), ('2013', 'ADP')],
#  [('Google', 'NOUN'), ('Google', 'ADP')],
#  [('Twitter', 'NOUN'), ('Twitter', 'ADP')],
#  [('2015', 'NUM'), ('2015', 'ADP')],
#  [('that', 'ADP'), ('that', 'DET')],
#  [('Google', 'NOUN'), ('Google', 'ADP')],
#  [('Twitter', 'NOUN'), ('Twitter', 'ADP')],
#  [('firehose', 'NOUN'), ('firehose', 'ADP')],
#  [('Twitter', 'NOUN'), ('Twitter', 'ADP')],
#  [('online', 'NOUN'), ('online', 'ADP')],
#  [('interact', 'NOUN'), ('interact', 'ADP')],
#  [('messages', 'VERB'), ('messages', 'ADP')],
#  [('known', 'VERB'), ('known', 'ADJ')],
#  [('tweets', 'NOUN'), ('tweets', 'ADP')],
#  [('domineering', 'VERB'), ('domineering', 'ADP')],
#  [('personality', 'NOUN'), ('personality', 'ADP')],
#  [('2018', 'NUM'), ('2018', 'ADP')],
#  [('FIFA', 'NOUN'), ('FIFA', 'ADP')],
#  [('Cup', 'NOUN'), ('Cup', 'ADP')],
#  [('21st', 'NOUN'), ('21st', 'ADP')],
#  [('FIFA', 'NOUN'), ('FIFA', 'ADP')],
#  [('Cup', 'NOUN'), ('Cup', 'ADP')],
#  [('tournament', 'NOUN'), ('tournament', 'ADP')],
#  [('contested', 'VERB'), ('contested', 'ADP')],
#  [('Cup', 'NOUN'), ('Cup', 'ADP')],
#  [('Show', 'NOUN'), ('Show', 'ADP')],
#  [('trips', 'NOUN'), ('trips', 'ADP')],
#  [('Show', 'NOUN'), ('Show', 'ADP')],
#  [('arriving', 'VERB'), ('arriving', 'ADP')],
#  [('NASA', 'NOUN'), ('NASA', 'ADP')],
#  [('invited', 'VERB'), ('invited', 'ADP')],
#  [('ICESAT-2', 'NOUN'), ('ICESAT-2', 'ADP')],
#  [('Satellite', 'NOUN'), ('Satellite', 'ADP')]]

# %% [markdown]
# ### Comparing the tagging accuracies of the modifications from Method -2 with the vanilla Viterbi algorithm and Method -1

# %% [markdown]
# -- Vanilla Viterbi gave 91% accuracy and with modification of method 2 (for unknown words running unigram and regex tagger) accuracy obtained is 95%

# %% [markdown]
# -- Method 1 (for unknown words using only transition probability) gave 94% accuracy and Method 2 (for unknown words running unigram and regex tagger) accuracy obtained is 95%

# %% [markdown]
# ### Cases which were incorrectly tagged by original POS tagger and got corrected by Method -2

# %% [markdown]
# 1. Numbers like 2018,2013 etc are getting tagged correctly as NUM

# %% [markdown]
# 2. Android, Google, twitter, NASA identified as Noun correctly

# %% [markdown]
# 3. Tournament, cups got identified as Noun correctly
